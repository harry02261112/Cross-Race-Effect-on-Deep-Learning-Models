# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns 
import random

# %%
# %cd "/content/drive/MyDrive/Final"
# Out:
# /content/drive/.shortcut-targets-by-id/1ujc0rEwHZPLX-PmA8l7W_lrmuFS-3EZr/Final

# %%
ls
# Out:
#  Dataset/                                old_proposal/
# 'feature_maps (1).jpg'                   roLabelImg-master.zip
# 'Feedback Questions.gdoc'                Tasks.gdoc
#  labeling_tutorial.mov                  'Uncropped Dataset.ipynb'
# 'Links for age estimation papers.gdoc'   yolov5/
#  New_Final_Cross_Race_Effect/            yolov5s.pt

# %% [markdown]
# # Data Loading

# %%
#!tar -xvf "./Dataset/part1.tar.gz"
#!tar -xvf "./Dataset/part2.tar.gz"
#!tar -xvf "./Dataset/part3.tar.gz"
#!tar -zxvf "./Dataset/crop_part1.tar.gz"
#!tar -zxvf "./Dataset/UTKFace.tar.gz"

# %%
import os
from os.path import isfile, join

crop_path = "./Dataset/UTKFace/"

crop_list = [f for f in os.listdir(crop_path) if isfile(join(crop_path,f)) and f.endswith(".jpg")]

# %%
import pandas as pd 

age_list = []
gender_list = []
race_list = []

for crop_img_name in crop_list:
  
  img_name = crop_img_name.split("_")

  age_list.append(int(img_name[0]))
  gender_list.append(img_name[1])
  race_list.append(img_name[2])

df = pd.DataFrame({
    "img":crop_list,
    "age":age_list,
    "gender":gender_list,
    "race":race_list
})

df[100:120]
# Out:
#                                        img  age gender race
# 100  61_0_3_20170119211849977.jpg.chip.jpg   61      0    3
# 101  61_0_3_20170119211851089.jpg.chip.jpg   61      0    3
# 102  61_0_3_20170119211851937.jpg.chip.jpg   61      0    3
# 103  61_0_3_20170119211819474.jpg.chip.jpg   61      0    3
# 104  61_0_3_20170119211835296.jpg.chip.jpg   61      0    3
# 105  61_0_3_20170119211853505.jpg.chip.jpg   61      0    3
# 106  61_0_3_20170119211852753.jpg.chip.jpg   61      0    3
# 107  63_0_3_20170119205921327.jpg.chip.jpg   63      0    3
# 108  61_1_3_20170119211928409.jpg.chip.jpg   61      1    3
# 109  61_1_3_20170119211903336.jpg.chip.jpg   61      1    3
# 110  61_0_3_20170119211856632.jpg.chip.jpg   61      0    3
# 111  61_0_3_20170119211905592.jpg.chip.jpg   61      0    3
# 112  61_1_3_20170119211810610.jpg.chip.jpg   61      1    3
# 113  61_0_3_20170119211907034.jpg.chip.jpg   61      0    3
# 114  61_0_3_20170119211857657.jpg.chip.jpg   61      0    3
# 115  62_1_3_20170119211556000.jpg.chip.jpg   62      1    3
# 116  63_0_3_20170119211952608.jpg.chip.jpg   63      0    3
# 117  63_0_3_20170119211951488.jpg.chip.jpg   63      0    3
# 118  63_0_3_20170119211934680.jpg.chip.jpg   63      0    3
# 119  64_0_3_20170119164145677.jpg.chip.jpg   64      0    3

# %% [markdown]
# # Data Visualization

# %%
# Some images was not labeled with race
df['race'].value_counts()
# Out:
# 0                                 10078
# 1                                  4526
# 3                                  3975
# 2                                  3434
# 4                                  1692
# 20170116174525125.jpg.chip.jpg        1
# 20170109150557335.jpg.chip.jpg        1
# 20170109142408075.jpg.chip.jpg        1
# Name: race, dtype: int64

# %%
# Find the img location, find the location from without labeling
outliers = []
for i,race in enumerate(df["race"]):
  if(race == "20170116174525125.jpg.chip.jpg" or race == "20170109150557335.jpg.chip.jpg" or race == "20170109142408075.jpg.chip.jpg"):
    print(i)
    outliers.append(i)
# Out:
# 3374
# 15800
# 15805

# %%
# show the image for manual label
for outlier in outliers:
  img = plt.imread(join(crop_path,df["img"][outlier]))
  plt.imshow(img)
  plt.colorbar()
  plt.show()

# %%
# label the images 
df["race"][outliers[0]] = "1"
df["race"][outliers[1]] = "3"
df["race"][outliers[2]] = "1"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
plt.figure(figsize=(5,5))
df['race'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie Chart of race", fontdict={'fontsize': 14})
plt.tight_layout()

# %%
age_range_list = []

for age in df["age"]:
  if(int(age) < 10):
      # set 20-24 as class 0
      age_range_list.append(0)
  elif(int(age)>=10 and int(age) < 20):
      # set 25-29 as class 1
      age_range_list.append(1)
  elif(int(age)>=20 and int(age) < 30):
      # set 30-34 as class 2
       age_range_list.append(2)
  elif(int(age)>=30 and int(age) < 40):
  #     # set 35-39 as class 3
       age_range_list.append(3)
  elif(int(age)>=40 and int(age) < 50):
  #     # set 40-44 as class 4
       age_range_list.append(4)
  elif(int(age)>=50 and int(age) < 60):
  #     # set 40-44 as class 4
       age_range_list.append(5)
  elif(int(age)>=60):
       # set 45-49 as class 5
       age_range_list.append(6)

df["age_range"] = age_range_list
#df["age_range"] = age_range_list
print(df.shape)
# Out:
# (23708, 5)

# %%
plt.figure(figsize=(5,5))
df['age_range'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie Chart of age range", fontdict={'fontsize': 14})
plt.tight_layout()

# %% [markdown]
# # Data Setup

# %%
race_num  = 'fulldataset'

# %%
## Additional External Libraries (Deep Learning)
import time
import datetime
import torchvision
import torch
import random
from sklearn.model_selection import train_test_split
from skimage import io
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms as tfs
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader,SubsetRandomSampler
from PIL import Image
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torchsummary import summary

gpu_boole = torch.cuda.is_available()

# %%
X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(df["img"], df["age_range"], test_size=0.1, random_state=601675, stratify=df["age_range"])
X_train_age, X_val_age, y_train_age, y_val_age = train_test_split(X_train_age, y_train_age, test_size=0.1, random_state=601675, stratify=y_train_age)

# %%
X_train_age
# Out:
# 18367     3_1_0_20170110213304238.jpg.chip.jpg
# 15427    24_1_0_20170105183618095.jpg.chip.jpg
# 2509     26_0_3_20170119183546909.jpg.chip.jpg
# 8296     24_1_4_20170117150622299.jpg.chip.jpg
# 20396    29_1_0_20170104021759835.jpg.chip.jpg
#                          ...
# 21185    45_1_0_20170103183543298.jpg.chip.jpg
# 6252     53_1_0_20170117163710642.jpg.chip.jpg
# 1729     50_0_3_20170119171601064.jpg.chip.jpg
# 14397    14_1_0_20170109213221821.jpg.chip.jpg
# 17870    85_1_0_20170110183134095.jpg.chip.jpg
# Name: img, Length: 19203, dtype: object

# %%
crop_image_path = "./Dataset/UTKFace"

img_transform = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.PILToTensor(),
])


class Crop_Face_Data(Dataset):
    def __init__(self, 
                 X_train,
                 y_train,
                 data_dir = crop_image_path,
                 transforms = img_transform, 
                 use_memory = False):
      #if load all data into memeory 
      self.use_memory = use_memory
      self.transform = transforms
      self.data = []
      self.labels = []
      for i,img_name in enumerate(X_train):
        img_path = join(data_dir, img_name)
        if self.use_memory:
          self.data.append(Image.open(img_path))
        else:
          self.data.append(img_path)
        self.labels.append(y_train.tolist()[i])

    def __len__(self):
      return len(self.labels)

    def __getitem__(self, idx):
      if self.use_memory:
        img = self.data[idx]
      else:
        img = Image.open(self.data[idx])
      if self.transform:
        img = self.transform(img)
      return img, float(self.labels[idx])

# %%
Batch_Size = 8

use_memory = True

train_age_dataset = Crop_Face_Data(X_train = X_train_age, 
                                        y_train = y_train_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
train_age_dataloader = DataLoader(train_age_dataset, batch_size=Batch_Size, shuffle=True)

val_age_dataset = Crop_Face_Data(X_train = X_val_age, 
                                        y_train = y_val_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
val_age_dataloader = DataLoader(val_age_dataset, batch_size=Batch_Size, shuffle=True)

test_age_dataset = Crop_Face_Data(X_train = X_test_age, 
                                        y_train = y_test_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
test_age_dataloader = DataLoader(test_age_dataset, batch_size=Batch_Size, shuffle=True)

# %%
def train(model,
          model_name,
          optimizer,
          loss,
          lr,
          epochs,
          train_dataloader,
          val_dataloader,
          test_dataloader,
          **kwargs):
    """
    
    """
    net = model.cuda()

    optimizer = optimizer(net.parameters(), lr = lr)
    loss_metric = loss()

    val_loss_old = 10000
    val_loss_unchanged_counter = 0

    train_loss_list = []
    val_acc_list = []
    train_acc_list = []
    val_loss_list = []

    
    print("Start Training")
    #training loop:
    for epoch in range(epochs):
      time1 = time.time() #timekeeping

      correct = 0
      total = 0
      loss_sum = 0

      for i, (x,y) in enumerate(train_dataloader):

        x = x.float()
        y = y.float()

        if gpu_boole:
          x = x.cuda()
          y = y.cuda()

        #loss calculation and gradient update:

        if i > 0 or epoch > 0:
          optimizer.zero_grad()
        outputs = net.forward(x)
        #print("y:",y)
        #print("outputs:",outputs)
        loss = loss_metric(outputs,y.to(torch.int64))
        loss.backward()

        loss_sum += loss

        ##performing update:
        optimizer.step()

        total += y.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct += (predicted.float() == y.float()).sum()

      #print("total:",total)
      #print("correct:",correct)

      train_acc, train_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

      train_loss_list.append(train_loss)
      train_acc_list.append(train_acc)


      with torch.no_grad():

          correct = 0
          total = 0
          loss_sum = 0

          for i, (x,y) in enumerate(val_dataloader):

            x = x.float()
            y = y.float()

            if gpu_boole:
              x = x.cuda()
              y = y.cuda()
            
            outputs = net.forward(x)
            loss = loss_metric(outputs,y.to(torch.int64))

            total += y.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted.float() == y.float()).sum()
            loss_sum += loss

          val_acc, val_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

          val_acc_list.append(val_acc)
          val_loss_list.append(val_loss)

          if(val_loss_old == val_loss):
            val_loss_unchanged_counter+=1
          else:
            torch.save({
            'epoch': EPOCH,
            'model_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_acc': val_acc_list,
            'train_acc': train_acc_list,
            'val_loss': val_loss_list,
            'train_loss': train_loss_list,
            }, f"./New_Final_Cross_Race_Effect/race_{race_num}_checkpts/{model_name}_race_{race_num}_age_best.pt")
            val_loss_unchanged_counter = 0
          val_loss_old = val_loss

          print("Epoch",epoch+1,':')

          print("-"*20)
          print('Train accuracy: %f %%' % (100.0 * train_acc))
          print('Train loss: %f' % (train_loss))
          print("-"*20)
          print('Validation accuracy: %f %%' % (100.0 * val_acc))
          print('Validation loss: %f' % (val_loss))
          print("-"*20)

          time2 = time.time() #timekeeping
          print('Elapsed time for epoch:',time2 - time1,'s')
          print('ETA of completion:',(time2 - time1)*(epochs - epoch - 1)/60,'minutes')
          print()

          if(val_loss_unchanged_counter == 10):
            print("validation loss hasn't changed in 10 epochs: end training")
            break

    plt.figure(figsize=(10,10))
    plt.plot(torch.tensor(train_loss_list).cpu().detach().numpy(), '-o', label = 'train_loss', color = 'orange')
    plt.xlabel('Epochs')
    plt.ylabel('Train Loss')
    plt.legend()
    plt.show()


    plt.figure(figsize=(10,10))
    plt.plot(torch.tensor(val_acc_list).cpu().detach().numpy(), '-o', label = 'val_acc', color = 'blue')
    plt.xlabel('Epochs')
    plt.ylabel('Val Accuracy')
    plt.legend()
    plt.show()

    with torch.no_grad():

        correct = 0
        total = 0
        loss_sum = 0

        for i, (x,y) in enumerate(test_dataloader):

          x = x.float()
          y = y.float()

          if gpu_boole:
            x = x.cuda()
            y = y.cuda()

          outputs = net.forward(x)
          loss = loss_metric(outputs,y.to(torch.int64))

          total += y.size(0)
          _, predicted = torch.max(outputs.data, 1)
          correct += (predicted.float() == y.float()).sum()

          loss_sum += loss

        test_acc, test_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

        print("-"*20)
        print('Test accuracy: %f %%' % (100.0 * test_acc))
        print('Test loss: %f' % (test_loss))
        print("-"*20)

# %% [markdown]
# # Resnet 101

# %%
# import torchvision.models as models

# class ResNet101(nn.Module):
#   def __init__(self, in_channels=3):
#     super(ResNet101, self).__init__()

#     # Load a pretrained resnet model from torchvision.models in Pytorch
#     self.model = models.resnet101(pretrained=True)

#     # Change the input layer to take Grayscale image, instead of RGB images. 
#     # Hence in_channels is set as 1 or 3 respectively
#     # original definition of the first layer on the ResNet class
#     # self.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
#     self.model.conv1 = nn.Conv2d(in_channels, 64,3)

#     #i=0
#     #for param in self.model.parameters():
#     #    if i>39 and i<343:
#     #        param.requires_grad = False
#     #    i+=1 
    
#     # Change the output layer to output 10 classes instead of 1000 classes
#     num_ftrs = self.model.fc.in_features
#     self.model.fc = nn.Linear(num_ftrs, 7)

#   def forward(self, x):
#     x = self.model(x)
#     return F.log_softmax(x,dim=1)

# %%
# with torch.no_grad():
#   dummy_net = ResNet101()
#   dummy_net = dummy_net.cuda()
#   summary(dummy_net, (3, 224, 224))

# %%
# ## Hyperparameters
# EPOCH = 100
# LR = 0.005

# ## Setting up the model, optimizer, and loss function
# model = ResNet101()
# model_name = "resnet101"
# optimizer = optim.SGD
# loss_f = nn.NLLLoss

# %%
# ## Run Training Loop
# out = train(model,
#             model_name, 
#             optimizer, 
#             loss_f,
#             LR,
#             epochs = EPOCH,
#             train_dataloader = train_age_dataloader,
#             val_dataloader = val_age_dataloader,
#             test_dataloader = test_age_dataloader)

# %% [markdown]
# # VGG16

# %%
import torchvision.models as models

class VGG16(nn.Module):
  def __init__(self, in_channels=3):
    super(VGG16, self).__init__()

    # Load a pretrained resnet model from torchvision.models in Pytorch
    self.model = models.vgg16(pretrained=True)

    # Change the input layer to take Grayscale image, instead of RGB images. 
    # Hence in_channels is set as 1 or 3 respectively
    # original definition of the first layer on the ResNet class
    # self.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    self.model.conv1 = nn.Conv2d(in_channels, 64,3)

    i=0
    #for param in self.model.parameters():
    #    if i>39 and i<343:
    #        param.requires_grad = False
    #    i+=1 
    
    # Change the output layer to output 10 classes instead of 1000 classes
    num_ftrs = self.model.classifier[6].in_features
    self.model.classifier[6] = nn.Linear(num_ftrs, 7)

  def forward(self, x):
    x = self.model(x)
    return F.log_softmax(x,dim=1)

# %%
with torch.no_grad():
  dummy_net = VGG16()
  dummy_net = dummy_net.cuda()
  summary(dummy_net, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                    [-1, 7]          28,679
#               VGG-40                    [-1, 7]               0
# ================================================================
# Total params: 134,289,223
# Trainable params: 134,289,223
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.77
# Params size (MB): 512.27
# Estimated Total Size (MB): 731.62
# ----------------------------------------------------------------

# %%
## Hyperparameters
EPOCH = 100
LR = 0.001

## Setting up the model, optimizer, and loss function
model = VGG16()
model_name = "VGG16"
optimizer = optim.SGD
loss_f = nn.NLLLoss

# %%
## Run Training Loop
out = train(model, 
            model_name,
            optimizer, 
            loss_f,
            LR,
            epochs = EPOCH,
            train_dataloader = train_age_dataloader,
            val_dataloader = val_age_dataloader,
            test_dataloader = test_age_dataloader)
# Out:
# Start Training
# Epoch 1 :
# --------------------
# Train accuracy: 43.545280 %
# Train loss: 0.184598
# --------------------
# Validation accuracy: 46.298035 %
# Validation loss: 0.161135
# --------------------
# Elapsed time for epoch: 440.18752455711365 s
# ETA of completion: 726.3094155192375 minutes
#
# Epoch 2 :
# --------------------
# Train accuracy: 53.330208 %
# Train loss: 0.146860
# --------------------
# Validation accuracy: 54.967201 %
# Validation loss: 0.139950
# --------------------
# Elapsed time for epoch: 470.4435250759125 s
# ETA of completion: 768.3910909573237 minutes
#
# Epoch 3 :
# --------------------
# Train accuracy: 56.798416 %
# Train loss: 0.131507
# --------------------
# Validation accuracy: 54.358013 %
# Validation loss: 0.135813
# --------------------
# Elapsed time for epoch: 470.9367299079895 s
# ETA of completion: 761.3477133512497 minutes
#
# Epoch 4 :
# --------------------
# Train accuracy: 59.860439 %
# Train loss: 0.120933
# --------------------
# Validation accuracy: 54.404873 %
# Validation loss: 0.141385
# --------------------
# Elapsed time for epoch: 471.1311225891113 s
# ETA of completion: 753.8097961425781 minutes
#
# Epoch 5 :
# --------------------
# Train accuracy: 61.964272 %
# Train loss: 0.112974
# --------------------
# Validation accuracy: 59.090912 %
# Validation loss: 0.128024
# --------------------
# Elapsed time for epoch: 471.07800364494324 s
# ETA of completion: 745.8735057711601 minutes
#
# Epoch 6 :
# --------------------
# Train accuracy: 64.729469 %
# Train loss: 0.104901
# --------------------
# Validation accuracy: 58.106838 %
# Validation loss: 0.128627
# --------------------
# Elapsed time for epoch: 471.9841055870056 s
# ETA of completion: 739.4417654196421 minutes
#
# Epoch 7 :
# --------------------
# Train accuracy: 67.093681 %
# Train loss: 0.096855
# --------------------
# Validation accuracy: 61.012184 %
# Validation loss: 0.125316
# --------------------
# Elapsed time for epoch: 472.9662411212921 s
# ETA of completion: 733.0976737380028 minutes
#
# Epoch 8 :
# --------------------
# Train accuracy: 69.499557 %
# Train loss: 0.089073
# --------------------
# Validation accuracy: 59.372074 %
# Validation loss: 0.139947
# --------------------
# Elapsed time for epoch: 472.1904032230377 s
# ETA of completion: 724.0252849419911 minutes
#
# Epoch 9 :
# --------------------
# Train accuracy: 72.535538 %
# Train loss: 0.081322
# --------------------
# Validation accuracy: 58.528584 %
# Validation loss: 0.133827
# --------------------
# Elapsed time for epoch: 472.2445378303528 s
# ETA of completion: 716.2375490427017 minutes
#
# Epoch 10 :
# --------------------
# Train accuracy: 75.701714 %
# Train loss: 0.073916
# --------------------
# Validation accuracy: 60.590439 %
# Validation loss: 0.142305
# --------------------
# Elapsed time for epoch: 472.76770210266113 s
# ETA of completion: 709.1515531539917 minutes
#
# Epoch 11 :
# --------------------
# Train accuracy: 77.972191 %
# Train loss: 0.065984
# --------------------
# Validation accuracy: 59.137768 %
# Validation loss: 0.163464
# --------------------
# Elapsed time for epoch: 472.8384759426117 s
# ETA of completion: 701.3770726482073 minutes
#
# Epoch 12 :
# --------------------
# Train accuracy: 80.706139 %
# Train loss: 0.058418
# --------------------
# Validation accuracy: 60.262417 %
# Validation loss: 0.179091
# --------------------
# Elapsed time for epoch: 473.38420820236206 s
# ETA of completion: 694.2968386967976 minutes
#
# Epoch 13 :
# --------------------
# Train accuracy: 83.325523 %
# Train loss: 0.051675
# --------------------
# Validation accuracy: 59.606373 %
# Validation loss: 0.177349
# --------------------
# Elapsed time for epoch: 472.8769552707672 s
# ETA of completion: 685.6715851426125 minutes
#
# Epoch 14 :
# --------------------
# Train accuracy: 85.153358 %
# Train loss: 0.046499
# --------------------
# Validation accuracy: 59.653236 %
# Validation loss: 0.201155
# --------------------
# Elapsed time for epoch: 472.90675377845764 s
# ETA of completion: 677.8330137491226 minutes
#
# Epoch 15 :
# --------------------
# Train accuracy: 87.137428 %
# Train loss: 0.041206
# --------------------
# Validation accuracy: 59.325211 %
# Validation loss: 0.191520
# --------------------
# Elapsed time for epoch: 473.60329389572144 s
# ETA of completion: 670.9379996856054 minutes
#
# Epoch 16 :
# --------------------
# Train accuracy: 88.939224 %
# Train loss: 0.036907
# --------------------
# Validation accuracy: 58.856606 %
# Validation loss: 0.179404
# --------------------
# Elapsed time for epoch: 473.6192021369934 s
# ETA of completion: 663.0668829917907 minutes
#
# Epoch 17 :
# --------------------
# Train accuracy: 90.392128 %
# Train loss: 0.031532
# --------------------
# Validation accuracy: 52.952206 %
# Validation loss: 0.266090
# --------------------
# Elapsed time for epoch: 474.0530197620392 s
# ETA of completion: 655.7733440041542 minutes
#
# Epoch 18 :
# --------------------
# Train accuracy: 91.720047 %
# Train loss: 0.027885
# --------------------
# Validation accuracy: 53.045921 %
# Validation loss: 0.285944
# --------------------
# Elapsed time for epoch: 472.90600061416626 s
# ETA of completion: 646.3048675060272 minutes
#
# Epoch 19 :
# --------------------
# Train accuracy: 92.766754 %
# Train loss: 0.025291
# --------------------
# Validation accuracy: 60.215557 %
# Validation loss: 0.225769
# --------------------
# Elapsed time for epoch: 473.6420714855194 s
# ETA of completion: 639.4167965054512 minutes
#
# Epoch 20 :
# --------------------
# Train accuracy: 93.615578 %
# Train loss: 0.022529
# --------------------
# Validation accuracy: 58.434868 %
# Validation loss: 0.234530
# --------------------
# Elapsed time for epoch: 472.2315340042114 s
# ETA of completion: 629.6420453389486 minutes
#
# Epoch 21 :
# --------------------
# Train accuracy: 94.948700 %
# Train loss: 0.017861
# --------------------
# Validation accuracy: 58.997189 %
# Validation loss: 0.262830
# --------------------
# Elapsed time for epoch: 473.9562268257141 s
# ETA of completion: 624.0423653205236 minutes
#
# Epoch 22 :
# --------------------
# Train accuracy: 95.287193 %
# Train loss: 0.017158
# --------------------
# Validation accuracy: 60.215557 %
# Validation loss: 0.247064
# --------------------
# Elapsed time for epoch: 473.03185081481934 s
# ETA of completion: 614.9414060592651 minutes
#
# Epoch 23 :
# --------------------
# Train accuracy: 95.391342 %
# Train loss: 0.016402
# --------------------
# Validation accuracy: 59.090912 %
# Validation loss: 0.248132
# --------------------
# Elapsed time for epoch: 473.3804383277893 s
# ETA of completion: 607.5048958539962 minutes
#
# Epoch 24 :
# --------------------
# Train accuracy: 95.958969 %
# Train loss: 0.014129
# --------------------
# Validation accuracy: 59.606373 %
# Validation loss: 0.318115
# --------------------
# Elapsed time for epoch: 473.43813490867615 s
# ETA of completion: 599.6883042176564 minutes
#
# Epoch 25 :
# --------------------
# Train accuracy: 96.479713 %
# Train loss: 0.013077
# --------------------
# Validation accuracy: 58.997189 %
# Validation loss: 0.294194
# --------------------
# Elapsed time for epoch: 472.7348163127899 s
# ETA of completion: 590.9185203909874 minutes
#
# Epoch 26 :
# --------------------
# Train accuracy: 96.422432 %
# Train loss: 0.012708
# --------------------
# Validation accuracy: 59.137768 %
# Validation loss: 0.273909
# --------------------
# Elapsed time for epoch: 473.50762581825256 s
# ETA of completion: 583.9927385091781 minutes
#
# Epoch 27 :
# --------------------
# Train accuracy: 97.370201 %
# Train loss: 0.010092
# --------------------
# Validation accuracy: 59.840672 %
# Validation loss: 0.320305
# --------------------
# Elapsed time for epoch: 473.95180559158325 s
# ETA of completion: 576.6413634697597 minutes
#
# Epoch 28 :
# --------------------
# Train accuracy: 97.302505 %
# Train loss: 0.009647
# --------------------
# Validation accuracy: 60.028118 %
# Validation loss: 0.331550
# --------------------
# Elapsed time for epoch: 472.7334728240967 s
# ETA of completion: 567.280167388916 minutes
#
# Epoch 29 :
# --------------------
# Train accuracy: 97.755554 %
# Train loss: 0.008549
# --------------------
# Validation accuracy: 60.543579 %
# Validation loss: 0.313753
# --------------------
# Elapsed time for epoch: 473.1473491191864 s
# ETA of completion: 559.8910297910372 minutes
#
# Epoch 30 :
# --------------------
# Train accuracy: 98.083633 %
# Train loss: 0.006910
# --------------------
# Validation accuracy: 60.449863 %
# Validation loss: 0.324417
# --------------------
# Elapsed time for epoch: 471.88672161102295 s
# ETA of completion: 550.5345085461935 minutes
#
# Epoch 31 :
# --------------------
# Train accuracy: 98.031555 %
# Train loss: 0.007182
# --------------------
# Validation accuracy: 59.044052 %
# Validation loss: 0.320340
# --------------------
# Elapsed time for epoch: 473.5715208053589 s
# ETA of completion: 544.6072489261627 minutes
#
# Epoch 32 :
# --------------------
# Train accuracy: 98.312767 %
# Train loss: 0.006523
# --------------------
# Validation accuracy: 59.184628 %
# Validation loss: 0.340516
# --------------------
# Elapsed time for epoch: 473.80856943130493 s
# ETA of completion: 536.9830453554789 minutes
#
# Epoch 33 :
# --------------------
# Train accuracy: 98.323181 %
# Train loss: 0.006330
# --------------------
# Validation accuracy: 60.590439 %
# Validation loss: 0.336431
# --------------------
# Elapsed time for epoch: 473.240709066391 s
# ETA of completion: 528.4521251241366 minutes
#
# Epoch 34 :
# --------------------
# Train accuracy: 98.323181 %
# Train loss: 0.006080
# --------------------
# Validation accuracy: 52.811623 %
# Validation loss: 0.365171
# --------------------
# Elapsed time for epoch: 472.7587683200836 s
# ETA of completion: 520.034645152092 minutes
#
# Epoch 35 :
# --------------------
# Train accuracy: 98.104462 %
# Train loss: 0.006811
# --------------------
# Validation accuracy: 59.278351 %
# Validation loss: 0.346330
# --------------------
# Elapsed time for epoch: 473.4895622730255 s
# ETA of completion: 512.9470257957777 minutes
#
# Epoch 36 :
# --------------------
# Train accuracy: 98.406502 %
# Train loss: 0.005727
# --------------------
# Validation accuracy: 59.981258 %
# Validation loss: 0.324219
# --------------------
# Elapsed time for epoch: 473.7689790725708 s
# ETA of completion: 505.35357767740885 minutes
#
# Epoch 37 :
# --------------------
# Train accuracy: 98.989746 %
# Train loss: 0.003551
# --------------------
# Validation accuracy: 61.293346 %
# Validation loss: 0.350197
# --------------------
# Elapsed time for epoch: 474.1372513771057 s
# ETA of completion: 497.844113945961 minutes
