# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
% matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns 
import random

# %%
# %cd "/content/drive/MyDrive/JHU courses/ML_class/Final"
# Out:
# /content/drive/MyDrive/JHU courses/ML_class/Final

# %%
# %ls
# Out:
#  Dataset/                                old_proposal/
# 'feature_maps (1).jpg'                   roLabelImg-master.zip
#  feature_maps.jpg                        Tasks.gdoc
# 'Feedback Questions.gdoc'               'Uncropped Dataset.ipynb'
#  labeling_tutorial.mov                   yolov5/
# 'Links for age estimation papers.gdoc'   yolov5s.pt
#  New_Final_Cross_Race_Effect/

# %% [markdown]
# # Data Loading

# %%
#!tar -xvf "./Dataset/part1.tar.gz"
#!tar -xvf "./Dataset/part2.tar.gz"
#!tar -xvf "./Dataset/part3.tar.gz"

# %%
#!tar -zxvf "./Dataset/crop_part1.tar.gz"
#!tar -zxvf "./Dataset/UTKFace.tar.gz"

# %%
import os
from os.path import isfile, join

crop_path = "./Dataset/UTKFace/"

crop_list = [f for f in os.listdir(crop_path) if isfile(join(crop_path,f)) and f.endswith(".jpg")]

# %%
import pandas as pd 

age_list = []
gender_list = []
race_list = []

for crop_img_name in crop_list:
  
  img_name = crop_img_name.split("_")

  age_list.append(int(img_name[0]))
  gender_list.append(img_name[1])
  race_list.append(img_name[2])

df = pd.DataFrame({
    "img":crop_list,
    "age":age_list,
    "gender":gender_list,
    "race":race_list
})

df
# Out:
#                                          img  age gender race
# 0      56_0_3_20170119180916188.jpg.chip.jpg   56      0    3
# 1      56_0_3_20170119183551541.jpg.chip.jpg   56      0    3
# 2      56_0_2_20170119180737540.jpg.chip.jpg   56      0    2
# 3      56_0_3_20170119174930466.jpg.chip.jpg   56      0    3
# 4      56_0_3_20170119180731484.jpg.chip.jpg   56      0    3
# ...                                      ...  ...    ...  ...
# 23703   1_0_2_20161219202914180.jpg.chip.jpg    1      0    2
# 23704   1_1_0_20161219202919508.jpg.chip.jpg    1      1    0
# 23705   2_1_2_20161219202825380.jpg.chip.jpg    2      1    2
# 23706   5_0_2_20161219202809316.jpg.chip.jpg    5      0    2
# 23707   1_0_2_20161219202752764.jpg.chip.jpg    1      0    2
#
# [23708 rows x 4 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Race

# %%
# Some images was not labeled with race
df['race'].value_counts()
# Out:
# 0                                 10078
# 1                                  4526
# 3                                  3975
# 2                                  3434
# 4                                  1692
# 20170116174525125.jpg.chip.jpg        1
# 20170109150557335.jpg.chip.jpg        1
# 20170109142408075.jpg.chip.jpg        1
# Name: race, dtype: int64

# %%
# Find the img location
outliers = []
for i,race in enumerate(df["race"]):
  if(race == "20170116174525125.jpg.chip.jpg" or race == "20170109150557335.jpg.chip.jpg" or race == "20170109142408075.jpg.chip.jpg"):
    print(i)
    outliers.append(i)
# Out:
# 3374
# 15800
# 15805

# %%
# show the image for manual label
for outlier in outliers:
  img = plt.imread(join(crop_path,df["img"][outlier]))

  plt.imshow(img)
  plt.show()

# %%
# label the images 
df["race"][outliers[0]] = "1"
df["race"][outliers[1]] = "3"
df["race"][outliers[2]] = "1"
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Check if every images are labeled
df['race'].value_counts()
# Out:
# 0    10078
# 1     4528
# 3     3976
# 2     3434
# 4     1692
# Name: race, dtype: int64

# %%
plt.figure(figsize=(5,5))
df['race'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie Chart of race", fontdict={'fontsize': 14})
plt.tight_layout()

# %% [markdown]
# ### devided race

# %%
race_num = "0"

race_num_list = df.index[df['race'] == race_num].tolist()

df_race = df.iloc[race_num_list]

# %%
#age_20_50_index = df_race.index[(df_race['age'] < 0)&(df_race['age'] >= 0)]
#df_20_50_race = df.iloc[age_20_50_index]
df_20_50_race = df_race

# %%
age_range_list = []

for age in df_20_50_race["age"]:
  if(int(age)>=0 and int(age) < 10):
      # set 0-10 as class 0
      age_range_list.append(0)
  elif(int(age)>=10 and int(age) < 20):
      # set 10-20 as class 1
      age_range_list.append(1)
  elif(int(age)>=20 and int(age) < 30):
      # set 20-30 as class 2
      age_range_list.append(2)
  elif(int(age)>=30 and int(age) < 40):
      # set 30-40 as class 3
      age_range_list.append(3)
  elif(int(age)>=40 and int(age) < 50):
      # set 40-50 as class 4
      age_range_list.append(4)
  elif(int(age)>=50 and int(age) < 60):
      # set 50-60 as class 5
      age_range_list.append(5)
  elif(int(age) >= 60):
      # set 60> as class 5
      age_range_list.append(6)

df_20_50_race["age_range"] = age_range_list
df_20_50_race
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                          img  age gender race  age_range
# 7      56_1_0_20170119202536518.jpg.chip.jpg   56      1    0          5
# 27     58_0_0_20170119211727401.jpg.chip.jpg   58      0    0          5
# 58     59_0_0_20170119211444609.jpg.chip.jpg   59      0    0          5
# 59     60_0_0_20170119204301455.jpg.chip.jpg   60      0    0          6
# 60     60_0_0_20170119145422774.jpg.chip.jpg   60      0    0          6
# ...                                      ...  ...    ...  ...        ...
# 23685   7_0_0_20161219201514284.jpg.chip.jpg    7      0    0          0
# 23695   1_0_0_20161219202455708.jpg.chip.jpg    1      0    0          0
# 23698   1_0_0_20161219203009924.jpg.chip.jpg    1      0    0          0
# 23699   1_1_0_20161219203021180.jpg.chip.jpg    1      1    0          0
# 23704   1_1_0_20161219202919508.jpg.chip.jpg    1      1    0          0
#
# [10078 rows x 5 columns]

# %%
alist = np.array(df_20_50_race["age"]).astype("int")
plt.figure(figsize=(10,10))
sns.countplot(x=np.sort(alist), data=df_20_50_race, palette = 'flare')
ax = plt.gca()
plt.title("race", fontdict={'fontsize': 14})
plt.show()

# %%
df_20_50_race["age_range"].value_counts()
# Out:
# 2    1986
# 6    1811
# 3    1749
# 5    1368
# 4    1115
# 0    1106
# 1     943
# Name: age_range, dtype: int64

# %%
plt.figure(figsize=(5,5))
df_20_50_race['age_range'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie Chart of age range", fontdict={'fontsize': 14})
plt.tight_layout()

# %% [markdown]
# ### randomly choose 1082 images

# %%
randomlist = random.sample(range(len(df_20_50_race)), 1692)
df_rand = df_20_50_race.iloc[randomlist]
df_rand
# Out:
#                                          img  age gender race  age_range
# 21327  41_1_0_20170103183002200.jpg.chip.jpg   41      1    0          4
# 5699   10_0_0_20170116201328751.jpg.chip.jpg   10      0    0          1
# 19365  52_0_0_20170104210032733.jpg.chip.jpg   52      0    0          5
# 17874  85_1_0_20170110183410318.jpg.chip.jpg   85      1    0          6
# 21220  35_1_0_20170103182149977.jpg.chip.jpg   35      1    0          3
# ...                                      ...  ...    ...  ...        ...
# 1656   47_0_0_20170119202349909.jpg.chip.jpg   47      0    0          4
# 7554   41_0_0_20170117185342291.jpg.chip.jpg   41      0    0          4
# 14221   7_1_0_20170109193930338.jpg.chip.jpg    7      1    0          0
# 17388  65_0_0_20170111193847133.jpg.chip.jpg   65      0    0          6
# 862    80_0_0_20170120225045833.jpg.chip.jpg   80      0    0          6
#
# [1692 rows x 5 columns]

# %%
alist = np.array(df_rand["age"]).astype("int")
plt.figure(figsize=(10,10))
sns.countplot(x=np.sort(alist), data=df_rand, palette = 'flare')
ax = plt.gca()
plt.title("race", fontdict={'fontsize': 14})
plt.show()

# %%
plt.figure(figsize=(5,5))
df_rand['age_range'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Pie Chart of age range", fontdict={'fontsize': 14})
plt.tight_layout()

# %% [markdown]
# # Data setup

# %%
## Additional External Libraries (Deep Learning)
import time
import datetime
import torchvision
import torch
import random
from sklearn.model_selection import train_test_split
from skimage import io
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms as tfs
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader,SubsetRandomSampler
from PIL import Image
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torchsummary import summary

gpu_boole = torch.cuda.is_available()

# %%
X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(df_rand["img"], df_rand["age_range"], test_size=0.1, random_state=601, stratify=df_rand["age_range"])
X_train_age, X_val_age, y_train_age, y_val_age = train_test_split(X_train_age, y_train_age, test_size=0.1, random_state=601, stratify=y_train_age)

# %%
crop_image_path = "./Dataset/UTKFace"

img_transform = transforms.Compose([
        transforms.Resize((256, 256)), 
        transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.PILToTensor(),
        transforms.AutoAugment(transforms.AutoAugmentPolicy.IMAGENET),
        transforms.ConvertImageDtype(torch.float)
])


class Crop_Face_Data(Dataset):
    def __init__(self, 
                 X_train,
                 y_train,
                 data_dir = crop_image_path,
                 transforms = img_transform, 
                 use_memory = False):
      #if load all data into memeory 
      self.use_memory = use_memory
      self.transform = transforms
      self.data = []
      self.labels = []
      for i,img_name in enumerate(X_train):
        img_path = join(data_dir, img_name)
        if self.use_memory:
          self.data.append(Image.open(img_path))
        else:
          self.data.append(img_path)
        self.labels.append(y_train.tolist()[i])

    def __len__(self):
      return len(self.labels)

    def __getitem__(self, idx):
      if self.use_memory:
        img = self.data[idx]
      else:
        img = Image.open(self.data[idx])
      if self.transform:
        img = self.transform(img)
      return img, float(self.labels[idx])

# %%
Batch_Size = 16

use_memory = True

train_age_dataset = Crop_Face_Data(X_train = X_train_age, 
                                        y_train = y_train_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
train_age_dataloader = DataLoader(train_age_dataset, batch_size=Batch_Size, shuffle=True)

val_age_dataset = Crop_Face_Data(X_train = X_val_age, 
                                        y_train = y_val_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
val_age_dataloader = DataLoader(val_age_dataset, batch_size=Batch_Size, shuffle=True)

test_age_dataset = Crop_Face_Data(X_train = X_test_age, 
                                        y_train = y_test_age, 
                                        data_dir = crop_image_path, 
                                        transforms=img_transform, 
                                        use_memory = use_memory)
test_age_dataloader = DataLoader(test_age_dataset, batch_size=Batch_Size, shuffle=True)

# %%
def train(model,
          model_name,
          optimizer,
          loss,
          lr,
          epochs,
          train_dataloader,
          val_dataloader,
          test_dataloader,
          **kwargs):
    """
    
    """
    ##TODO: Implement a training loop

    net = model.cuda()

    optimizer = optimizer(net.parameters(), lr = lr)
    loss_metric = loss()

    val_loss_old = 10000
    val_loss_unchanged_counter = 0

    train_loss_list = []
    val_acc_list = []
    train_acc_list = []
    val_loss_list = []

    
    print("Start Training")
    #training loop:
    for epoch in range(epochs):
      time1 = time.time() #timekeeping

      correct = 0
      total = 0
      loss_sum = 0

      for i, (x,y) in enumerate(train_dataloader):

        x = x.float()
        y = y.float()

        if gpu_boole:
          x = x.cuda()
          y = y.cuda()

        #loss calculation and gradient update:

        if i > 0 or epoch > 0:
          optimizer.zero_grad()
        outputs = net.forward(x)
        #print("y:",y)
        #print("outputs:",outputs)
        loss = loss_metric(outputs,y.to(torch.int64))
        loss.backward()

        loss_sum += loss

        ##performing update:
        optimizer.step()

        total += y.size(0)
        _, predicted = torch.max(outputs.data, 1)
        correct += (predicted.float() == y.float()).sum()

      #print("total:",total)
      #print("correct:",correct)

      train_acc, train_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

      train_loss_list.append(train_loss)
      train_acc_list.append(train_acc)


      with torch.no_grad():

          correct = 0
          total = 0
          loss_sum = 0

          for i, (x,y) in enumerate(val_dataloader):

            x = x.float()
            y = y.float()

            if gpu_boole:
              x = x.cuda()
              y = y.cuda()
            
            outputs = net.forward(x)
            loss = loss_metric(outputs,y.to(torch.int64))

            total += y.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted.float() == y.float()).sum()
            loss_sum += loss

          val_acc, val_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

          val_acc_list.append(val_acc)
          val_loss_list.append(val_loss)

          if(val_loss_old == val_loss):
            val_loss_unchanged_counter+=1
          else:
            torch.save({
            'epoch': EPOCH,
            'model_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_acc': val_acc_list,
            'train_acc': train_acc_list,
            'val_loss': val_loss_list,
            'train_loss': train_loss_list,
            }, f"./New_Final_Cross_Race_Effect/race_{race_num}_checkpts/{model_name}_race_{race_num}_age_best.pt")
            val_loss_unchanged_counter = 0
          val_loss_old = val_loss

          if(100.0 *(train_acc-val_acc)<=10):
            torch.save({
            'epoch': EPOCH,
            'model_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_acc': val_acc_list,
            'train_acc': train_acc_list,
            'val_loss': val_loss_list,
            'train_loss': train_loss_list,
            }, f"/content/drive/MyDrive/JHU courses/ML_class/Final/New_Final_Cross_Race_Effect/race_{race_num}_checkpts/Before_overfitting_{model_name}_race_{race_num}_age_best.pt")

          print("Epoch",epoch+1,':')

          print("-"*20)
          print('Train accuracy: %f %%' % (100.0 * train_acc))
          print('Train loss: %f' % (train_loss))
          print("-"*20)
          print('Validation accuracy: %f %%' % (100.0 * val_acc))
          print('Validation loss: %f' % (val_loss))
          print("-"*20)

          time2 = time.time() #timekeeping
          print('Elapsed time for epoch:',time2 - time1,'s')
          print('ETA of completion:',(time2 - time1)*(epochs - epoch - 1)/60,'minutes')
          print()

          if(val_loss_unchanged_counter == 10):
            print("validation loss hasn't changed in 10 epochs: end training")
            break

    plt.figure(figsize=(10,10))
    plt.plot(torch.tensor(train_loss_list).cpu().detach().numpy(), '-o', label = 'train_loss', color = 'orange')
    plt.xlabel('Epochs')
    plt.ylabel('Train Loss')
    plt.legend()
    plt.show()


    plt.figure(figsize=(10,10))
    plt.plot(torch.tensor(val_acc_list).cpu().detach().numpy(), '-o', label = 'val_acc', color = 'blue')
    plt.xlabel('Epochs')
    plt.ylabel('Val Accuracy')
    plt.legend()
    plt.show()

    with torch.no_grad():

        correct = 0
        total = 0
        loss_sum = 0

        for i, (x,y) in enumerate(test_dataloader):

          x = x.float()
          y = y.float()

          if gpu_boole:
            x = x.cuda()
            y = y.cuda()

          outputs = net.forward(x)
          loss = loss_metric(outputs,y.to(torch.int64))

          total += y.size(0)
          _, predicted = torch.max(outputs.data, 1)
          correct += (predicted.float() == y.float()).sum()

          loss_sum += loss

        test_acc, test_loss = correct / total, loss_sum.cpu().data.numpy().item()/total

        print("-"*20)
        print('Test accuracy: %f %%' % (100.0 * test_acc))
        print('Test loss: %f' % (test_loss))
        print("-"*20)

# %% [markdown]
# # VGG16

# %%
import torchvision.models as models

class VGG16(nn.Module):
  def __init__(self, in_channels=3):
    super(VGG16, self).__init__()

    # Load a pretrained resnet model from torchvision.models in Pytorch
    self.model = models.vgg16(pretrained=True)

    # Change the input layer to take Grayscale image, instead of RGB images. 
    # Hence in_channels is set as 1 or 3 respectively
    # original definition of the first layer on the ResNet class
    # self.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    self.model.conv1 = nn.Conv2d(in_channels, 64,3)

    i=0
    #for param in self.model.parameters():
    #    if i>39 and i<343:
    #        param.requires_grad = False
    #    i+=1 
    
    # Change the output layer to output 10 classes instead of 1000 classes
    num_ftrs = self.model.classifier[6].in_features
    self.model.classifier[6] = nn.Sequential(
        nn.Linear(num_ftrs, 1024),
        nn.ReLU(),
        nn.Linear(1024, 512),
        nn.ReLU(),
        nn.Dropout(),
        nn.Linear(512, 7))

  def forward(self, x):
    x = self.model(x)
    return F.log_softmax(x,dim=1)

# %%
with torch.no_grad():
  dummy_net = VGG16()
  dummy_net = dummy_net.cuda()
  summary(dummy_net, (3, 224, 224))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1024]       4,195,328
#              ReLU-40                 [-1, 1024]               0
#            Linear-41                  [-1, 512]         524,800
#              ReLU-42                  [-1, 512]               0
#           Dropout-43                  [-1, 512]               0
#            Linear-44                    [-1, 7]           3,591
#               VGG-45                    [-1, 7]               0
# ================================================================
# Total params: 138,984,263
# Trainable params: 138,984,263
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.80
# Params size (MB): 530.18
# Estimated Total Size (MB): 749.56
# ----------------------------------------------------------------

# %%
## Hyperparameters
EPOCH = 200
LR = 0.0001

## Setting up the model, optimizer, and loss function
model = VGG16()
model_name = "VGG16"
optimizer = optim.Adam
loss_f = nn.NLLLoss

# %%
## Run Training Loop
out = train(model, 
            model_name,
            optimizer, 
            loss_f,
            LR,
            epochs = EPOCH,
            train_dataloader = train_age_dataloader,
            val_dataloader = val_age_dataloader,
            test_dataloader = test_age_dataloader)
# Out:
# Start Training
# Epoch 1 :
# --------------------
# Train accuracy: 18.480644 %
# Train loss: 0.121182
# --------------------
# Validation accuracy: 16.339870 %
# Validation loss: 0.124812
# --------------------
# Elapsed time for epoch: 33.277066469192505 s
# ETA of completion: 110.3689371228218 minutes
#
# Epoch 2 :
# --------------------
# Train accuracy: 22.425129 %
# Train loss: 0.117966
# --------------------
# Validation accuracy: 29.411766 %
# Validation loss: 0.111134
# --------------------
# Elapsed time for epoch: 19.69471001625061 s
# ETA of completion: 64.99254305362702 minutes
#
# Epoch 3 :
# --------------------
# Train accuracy: 21.767715 %
# Train loss: 0.115286
# --------------------
# Validation accuracy: 24.836601 %
# Validation loss: 0.128190
# --------------------
# Elapsed time for epoch: 19.3978533744812 s
# ETA of completion: 63.68961857954661 minutes
#
# Epoch 4 :
# --------------------
# Train accuracy: 25.931337 %
# Train loss: 0.110640
# --------------------
# Validation accuracy: 36.601307 %
# Validation loss: 0.110384
# --------------------
# Elapsed time for epoch: 19.848737001419067 s
# ETA of completion: 64.83920753796896 minutes
#
# Epoch 5 :
# --------------------
# Train accuracy: 30.825420 %
# Train loss: 0.104340
# --------------------
# Validation accuracy: 32.679741 %
# Validation loss: 0.111487
# --------------------
# Elapsed time for epoch: 20.03123903274536 s
# ETA of completion: 65.10152685642242 minutes
#
# Epoch 6 :
# --------------------
# Train accuracy: 33.893353 %
# Train loss: 0.099940
# --------------------
# Validation accuracy: 35.947712 %
# Validation loss: 0.102611
# --------------------
# Elapsed time for epoch: 18.644742965698242 s
# ETA of completion: 60.284668922424316 minutes
#
# Epoch 7 :
# --------------------
# Train accuracy: 36.303871 %
# Train loss: 0.096042
# --------------------
# Validation accuracy: 40.522877 %
# Validation loss: 0.094302
# --------------------
# Elapsed time for epoch: 18.611335039138794 s
# ETA of completion: 59.866461042563124 minutes
#
# Epoch 8 :
# --------------------
# Train accuracy: 37.107380 %
# Train loss: 0.092947
# --------------------
# Validation accuracy: 40.522877 %
# Validation loss: 0.093975
# --------------------
# Elapsed time for epoch: 20.888190746307373 s
# ETA of completion: 66.84221038818359 minutes
#
# Epoch 9 :
# --------------------
# Train accuracy: 41.563187 %
# Train loss: 0.090334
# --------------------
# Validation accuracy: 43.137257 %
# Validation loss: 0.092667
# --------------------
# Elapsed time for epoch: 20.518529653549194 s
# ETA of completion: 65.3173193971316 minutes
#
# Epoch 10 :
# --------------------
# Train accuracy: 42.731922 %
# Train loss: 0.087507
# --------------------
# Validation accuracy: 41.830067 %
# Validation loss: 0.094850
# --------------------
# Elapsed time for epoch: 20.259241342544556 s
# ETA of completion: 64.1542642513911 minutes
#
# Epoch 11 :
# --------------------
# Train accuracy: 43.316288 %
# Train loss: 0.087925
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.086759
# --------------------
# Elapsed time for epoch: 20.704856157302856 s
# ETA of completion: 65.22029689550399 minutes
#
# Epoch 12 :
# --------------------
# Train accuracy: 42.951061 %
# Train loss: 0.084808
# --------------------
# Validation accuracy: 39.215687 %
# Validation loss: 0.097435
# --------------------
# Elapsed time for epoch: 20.94793462753296 s
# ETA of completion: 65.6368618329366 minutes
#
# Epoch 13 :
# --------------------
# Train accuracy: 43.243244 %
# Train loss: 0.083716
# --------------------
# Validation accuracy: 49.019608 %
# Validation loss: 0.078841
# --------------------
# Elapsed time for epoch: 18.831506729125977 s
# ETA of completion: 58.69152930577596 minutes
#
# Epoch 14 :
# --------------------
# Train accuracy: 45.653763 %
# Train loss: 0.081908
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.087348
# --------------------
# Elapsed time for epoch: 18.66087293624878 s
# ETA of completion: 57.84870610237122 minutes
#
# Epoch 15 :
# --------------------
# Train accuracy: 44.777210 %
# Train loss: 0.082498
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.082886
# --------------------
# Elapsed time for epoch: 20.582278966903687 s
# ETA of completion: 63.4620268146197 minutes
#
# Epoch 16 :
# --------------------
# Train accuracy: 45.434628 %
# Train loss: 0.082763
# --------------------
# Validation accuracy: 41.176472 %
# Validation loss: 0.087030
# --------------------
# Elapsed time for epoch: 21.550115823745728 s
# ETA of completion: 66.0870218594869 minutes
#
# Epoch 17 :
# --------------------
# Train accuracy: 44.996349 %
# Train loss: 0.081254
# --------------------
# Validation accuracy: 49.019608 %
# Validation loss: 0.078793
# --------------------
# Elapsed time for epoch: 21.04664444923401 s
# ETA of completion: 64.19226557016373 minutes
#
# Epoch 18 :
# --------------------
# Train accuracy: 47.333820 %
# Train loss: 0.077959
# --------------------
# Validation accuracy: 49.019608 %
# Validation loss: 0.080752
# --------------------
# Elapsed time for epoch: 20.28687834739685 s
# ETA of completion: 61.53686432043711 minutes
#
# Epoch 19 :
# --------------------
# Train accuracy: 50.182617 %
# Train loss: 0.077173
# --------------------
# Validation accuracy: 44.444447 %
# Validation loss: 0.083489
# --------------------
# Elapsed time for epoch: 18.803276538848877 s
# ETA of completion: 56.72321755886078 minutes
#
# Epoch 20 :
# --------------------
# Train accuracy: 45.799854 %
# Train loss: 0.077109
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.085669
# --------------------
# Elapsed time for epoch: 20.07176113128662 s
# ETA of completion: 60.21528339385986 minutes
#
# Epoch 21 :
# --------------------
# Train accuracy: 49.159973 %
# Train loss: 0.076663
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.075928
# --------------------
# Elapsed time for epoch: 29.923347234725952 s
# ETA of completion: 89.27131925026576 minutes
#
# Epoch 22 :
# --------------------
# Train accuracy: 51.205261 %
# Train loss: 0.074611
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.083674
# --------------------
# Elapsed time for epoch: 31.2325599193573 s
# ETA of completion: 92.65659442742665 minutes
#
# Epoch 23 :
# --------------------
# Train accuracy: 48.575603 %
# Train loss: 0.077586
# --------------------
# Validation accuracy: 45.751633 %
# Validation loss: 0.084483
# --------------------
# Elapsed time for epoch: 40.73980116844177 s
# ETA of completion: 120.18241344690323 minutes
#
# Epoch 24 :
# --------------------
# Train accuracy: 49.963482 %
# Train loss: 0.072703
# --------------------
# Validation accuracy: 47.712418 %
# Validation loss: 0.069673
# --------------------
# Elapsed time for epoch: 35.667821407318115 s
# ETA of completion: 104.62560946146647 minutes
#
# Epoch 25 :
# --------------------
# Train accuracy: 55.295837 %
# Train loss: 0.068080
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.079042
# --------------------
# Elapsed time for epoch: 40.8858847618103 s
# ETA of completion: 119.25049722194672 minutes
#
# Epoch 26 :
# --------------------
# Train accuracy: 52.958363 %
# Train loss: 0.069528
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.078461
# --------------------
# Elapsed time for epoch: 38.59689736366272 s
# ETA of completion: 111.93100235462188 minutes
#
# Epoch 27 :
# --------------------
# Train accuracy: 52.081810 %
# Train loss: 0.070646
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.081102
# --------------------
# Elapsed time for epoch: 40.308170318603516 s
# ETA of completion: 116.22189108530681 minutes
#
# Epoch 28 :
# --------------------
# Train accuracy: 53.542732 %
# Train loss: 0.067690
# --------------------
# Validation accuracy: 44.444447 %
# Validation loss: 0.093794
# --------------------
# Elapsed time for epoch: 38.96106505393982 s
# ETA of completion: 111.68838648796081 minutes
#
# Epoch 29 :
# --------------------
# Train accuracy: 54.054058 %
# Train loss: 0.068300
# --------------------
# Validation accuracy: 45.751633 %
# Validation loss: 0.084382
# --------------------
# Elapsed time for epoch: 30.177509784698486 s
# ETA of completion: 86.00590288639069 minutes
#
# Epoch 30 :
# --------------------
# Train accuracy: 53.907967 %
# Train loss: 0.068976
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.074258
# --------------------
# Elapsed time for epoch: 41.2623450756073 s
# ETA of completion: 116.90997771422069 minutes
#
# Epoch 31 :
# --------------------
# Train accuracy: 55.295837 %
# Train loss: 0.065871
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.079478
# --------------------
# Elapsed time for epoch: 37.128052711486816 s
# ETA of completion: 104.57734847068787 minutes
#
# Epoch 32 :
# --------------------
# Train accuracy: 58.217682 %
# Train loss: 0.065008
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.072588
# --------------------
# Elapsed time for epoch: 29.183542728424072 s
# ETA of completion: 81.7139196395874 minutes
#
# Epoch 33 :
# --------------------
# Train accuracy: 56.391533 %
# Train loss: 0.065134
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.080064
# --------------------
# Elapsed time for epoch: 42.07366418838501 s
# ETA of completion: 117.10503199100495 minutes
#
# Epoch 34 :
# --------------------
# Train accuracy: 58.729000 %
# Train loss: 0.063043
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.086784
# --------------------
# Elapsed time for epoch: 23.538032293319702 s
# ETA of completion: 65.12188934485117 minutes
#
# Epoch 35 :
# --------------------
# Train accuracy: 56.610668 %
# Train loss: 0.062359
# --------------------
# Validation accuracy: 49.019608 %
# Validation loss: 0.078083
# --------------------
# Elapsed time for epoch: 27.400914192199707 s
# ETA of completion: 75.3525140285492 minutes
#
# Epoch 36 :
# --------------------
# Train accuracy: 56.245434 %
# Train loss: 0.062484
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.079251
# --------------------
# Elapsed time for epoch: 41.420851945877075 s
# ETA of completion: 113.21699531873067 minutes
#
# Epoch 37 :
# --------------------
# Train accuracy: 57.852448 %
# Train loss: 0.061201
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.076772
# --------------------
# Elapsed time for epoch: 40.640121936798096 s
# ETA of completion: 110.40566459496816 minutes
#
# Epoch 38 :
# --------------------
# Train accuracy: 60.482109 %
# Train loss: 0.061348
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.072682
# --------------------
# Elapsed time for epoch: 13.583380699157715 s
# ETA of completion: 36.67512788772583 minutes
#
# Epoch 39 :
# --------------------
# Train accuracy: 58.217682 %
# Train loss: 0.062301
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.083585
# --------------------
# Elapsed time for epoch: 14.159540891647339 s
# ETA of completion: 37.994768059253694 minutes
#
# Epoch 40 :
# --------------------
# Train accuracy: 59.021187 %
# Train loss: 0.061302
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.074334
# --------------------
# Elapsed time for epoch: 44.23837757110596 s
# ETA of completion: 117.96900685628255 minutes
#
# Epoch 41 :
# --------------------
# Train accuracy: 59.824692 %
# Train loss: 0.061805
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.072853
# --------------------
# Elapsed time for epoch: 13.343634366989136 s
# ETA of completion: 35.36063107252121 minutes
#
# Epoch 42 :
# --------------------
# Train accuracy: 60.409058 %
# Train loss: 0.058235
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.073487
# --------------------
# Elapsed time for epoch: 36.11799144744873 s
# ETA of completion: 95.110710811615 minutes
#
# Epoch 43 :
# --------------------
# Train accuracy: 60.409058 %
# Train loss: 0.056958
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.074988
# --------------------
# Elapsed time for epoch: 45.034799575805664 s
# ETA of completion: 117.84105889002483 minutes
#
# Epoch 44 :
# --------------------
# Train accuracy: 62.892628 %
# Train loss: 0.055378
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.082243
# --------------------
# Elapsed time for epoch: 29.244998455047607 s
# ETA of completion: 76.03699598312377 minutes
#
# Epoch 45 :
# --------------------
# Train accuracy: 62.600441 %
# Train loss: 0.054979
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.072473
# --------------------
# Elapsed time for epoch: 21.905470371246338 s
# ETA of completion: 56.589131792386375 minutes
#
# Epoch 46 :
# --------------------
# Train accuracy: 62.381302 %
# Train loss: 0.056775
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.076007
# --------------------
# Elapsed time for epoch: 23.87560248374939 s
# ETA of completion: 61.280713041623436 minutes
#
# Epoch 47 :
# --------------------
# Train accuracy: 65.814468 %
# Train loss: 0.054153
# --------------------
# Validation accuracy: 41.830067 %
# Validation loss: 0.091373
# --------------------
# Elapsed time for epoch: 13.634057521820068 s
# ETA of completion: 34.76684668064117 minutes
#
# Epoch 48 :
# --------------------
# Train accuracy: 63.476990 %
# Train loss: 0.054944
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.079411
# --------------------
# Elapsed time for epoch: 35.31657004356384 s
# ETA of completion: 89.46864411036174 minutes
#
# Epoch 49 :
# --------------------
# Train accuracy: 64.426590 %
# Train loss: 0.053822
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.081773
# --------------------
# Elapsed time for epoch: 18.006025552749634 s
# ETA of completion: 45.31516430775324 minutes
#
# Epoch 50 :
# --------------------
# Train accuracy: 63.111763 %
# Train loss: 0.055134
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.087071
# --------------------
# Elapsed time for epoch: 16.354774951934814 s
# ETA of completion: 40.886937379837036 minutes
#
# Epoch 51 :
# --------------------
# Train accuracy: 61.504753 %
# Train loss: 0.055602
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.079105
# --------------------
# Elapsed time for epoch: 37.96935272216797 s
# ETA of completion: 94.29055926005046 minutes
#
# Epoch 52 :
# --------------------
# Train accuracy: 66.179695 %
# Train loss: 0.051468
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.083932
# --------------------
# Elapsed time for epoch: 24.97363257408142 s
# ETA of completion: 61.6016270160675 minutes
#
# Epoch 53 :
# --------------------
# Train accuracy: 65.668373 %
# Train loss: 0.051480
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.082412
# --------------------
# Elapsed time for epoch: 13.346459150314331 s
# ETA of completion: 32.69882491827011 minutes
#
# Epoch 54 :
# --------------------
# Train accuracy: 68.955444 %
# Train loss: 0.047277
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.088176
# --------------------
# Elapsed time for epoch: 17.422693967819214 s
# ETA of completion: 42.395221988360085 minutes
#
# Epoch 55 :
# --------------------
# Train accuracy: 66.398834 %
# Train loss: 0.051943
# --------------------
# Validation accuracy: 45.751633 %
# Validation loss: 0.084262
# --------------------
# Elapsed time for epoch: 20.517863750457764 s
# ETA of completion: 49.5848373969396 minutes
#
# Epoch 56 :
# --------------------
# Train accuracy: 65.887512 %
# Train loss: 0.049892
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.079495
# --------------------
# Elapsed time for epoch: 23.796849250793457 s
# ETA of completion: 57.1124382019043 minutes
#
# Epoch 57 :
# --------------------
# Train accuracy: 66.398834 %
# Train loss: 0.050120
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.073857
# --------------------
# Elapsed time for epoch: 13.001274108886719 s
# ETA of completion: 30.986369959513347 minutes
#
# Epoch 58 :
# --------------------
# Train accuracy: 66.325790 %
# Train loss: 0.049993
# --------------------
# Validation accuracy: 56.862747 %
# Validation loss: 0.072507
# --------------------
# Elapsed time for epoch: 33.78157901763916 s
# ETA of completion: 79.94973700841268 minutes
#
# Epoch 59 :
# --------------------
# Train accuracy: 69.539818 %
# Train loss: 0.046715
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.078259
# --------------------
# Elapsed time for epoch: 21.462724208831787 s
# ETA of completion: 50.4374018907547 minutes
#
# Epoch 60 :
# --------------------
# Train accuracy: 69.978088 %
# Train loss: 0.047821
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.078161
# --------------------
# Elapsed time for epoch: 17.070059537887573 s
# ETA of completion: 39.83013892173767 minutes
#
# Epoch 61 :
# --------------------
# Train accuracy: 68.590210 %
# Train loss: 0.045778
# --------------------
# Validation accuracy: 56.862747 %
# Validation loss: 0.088909
# --------------------
# Elapsed time for epoch: 20.94087290763855 s
# ETA of completion: 48.51302223602931 minutes
#
# Epoch 62 :
# --------------------
# Train accuracy: 70.270271 %
# Train loss: 0.046394
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.082393
# --------------------
# Elapsed time for epoch: 22.820186853408813 s
# ETA of completion: 52.486429762840274 minutes
#
# Epoch 63 :
# --------------------
# Train accuracy: 68.224983 %
# Train loss: 0.048026
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.086177
# --------------------
# Elapsed time for epoch: 12.840380907058716 s
# ETA of completion: 29.318869737784066 minutes
#
# Epoch 64 :
# --------------------
# Train accuracy: 70.708549 %
# Train loss: 0.044809
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.073072
# --------------------
# Elapsed time for epoch: 14.10671329498291 s
# ETA of completion: 31.975216801961263 minutes
#
# Epoch 65 :
# --------------------
# Train accuracy: 73.703438 %
# Train loss: 0.042006
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.081809
# --------------------
# Elapsed time for epoch: 15.598438262939453 s
# ETA of completion: 35.09648609161377 minutes
#
# Epoch 66 :
# --------------------
# Train accuracy: 73.192116 %
# Train loss: 0.040801
# --------------------
# Validation accuracy: 59.477127 %
# Validation loss: 0.075480
# --------------------
# Elapsed time for epoch: 18.930453777313232 s
# ETA of completion: 42.278013435999554 minutes
#
# Epoch 67 :
# --------------------
# Train accuracy: 72.169472 %
# Train loss: 0.042435
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.088120
# --------------------
# Elapsed time for epoch: 22.907082557678223 s
# ETA of completion: 50.777366336186724 minutes
#
# Epoch 68 :
# --------------------
# Train accuracy: 69.539818 %
# Train loss: 0.044583
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.076612
# --------------------
# Elapsed time for epoch: 24.72688889503479 s
# ETA of completion: 54.39915556907654 minutes
#
# Epoch 69 :
# --------------------
# Train accuracy: 73.265160 %
# Train loss: 0.040892
# --------------------
# Validation accuracy: 49.019608 %
# Validation loss: 0.086747
# --------------------
# Elapsed time for epoch: 13.644262313842773 s
# ETA of completion: 29.789972718556722 minutes
#
# Epoch 70 :
# --------------------
# Train accuracy: 74.068665 %
# Train loss: 0.041332
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.086458
# --------------------
# Elapsed time for epoch: 13.869421243667603 s
# ETA of completion: 30.05041269461314 minutes
#
# Epoch 71 :
# --------------------
# Train accuracy: 73.557343 %
# Train loss: 0.041519
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.096903
# --------------------
# Elapsed time for epoch: 20.65005850791931 s
# ETA of completion: 44.39762579202652 minutes
#
# Epoch 72 :
# --------------------
# Train accuracy: 74.360847 %
# Train loss: 0.040679
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.090845
# --------------------
# Elapsed time for epoch: 14.348358392715454 s
# ETA of completion: 30.609831237792967 minutes
#
# Epoch 73 :
# --------------------
# Train accuracy: 72.534698 %
# Train loss: 0.042191
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.074767
# --------------------
# Elapsed time for epoch: 18.66951870918274 s
# ETA of completion: 39.5171479344368 minutes
#
# Epoch 74 :
# --------------------
# Train accuracy: 75.967857 %
# Train loss: 0.039680
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.082382
# --------------------
# Elapsed time for epoch: 22.85307812690735 s
# ETA of completion: 47.99146406650543 minutes
#
# Epoch 75 :
# --------------------
# Train accuracy: 74.653038 %
# Train loss: 0.038558
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.094840
# --------------------
# Elapsed time for epoch: 19.066084146499634 s
# ETA of completion: 39.7210086385409 minutes
#
# Epoch 76 :
# --------------------
# Train accuracy: 77.282692 %
# Train loss: 0.037000
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.084999
# --------------------
# Elapsed time for epoch: 14.572685241699219 s
# ETA of completion: 30.116882832845054 minutes
#
# Epoch 77 :
# --------------------
# Train accuracy: 75.164352 %
# Train loss: 0.039152
# --------------------
# Validation accuracy: 57.516342 %
# Validation loss: 0.070171
# --------------------
# Elapsed time for epoch: 22.284644842147827 s
# ETA of completion: 45.683521926403046 minutes
#
# Epoch 78 :
# --------------------
# Train accuracy: 75.237404 %
# Train loss: 0.039422
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.073284
# --------------------
# Elapsed time for epoch: 17.799099445343018 s
# ETA of completion: 36.1915022055308 minutes
#
# Epoch 79 :
# --------------------
# Train accuracy: 75.675674 %
# Train loss: 0.038045
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.086164
# --------------------
# Elapsed time for epoch: 18.389775037765503 s
# ETA of completion: 37.08604632616043 minutes
#
# Epoch 80 :
# --------------------
# Train accuracy: 73.265160 %
# Train loss: 0.043541
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.094409
# --------------------
# Elapsed time for epoch: 21.067326545715332 s
# ETA of completion: 42.134653091430664 minutes
#
# Epoch 81 :
# --------------------
# Train accuracy: 75.310448 %
# Train loss: 0.039254
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.096402
# --------------------
# Elapsed time for epoch: 16.970614671707153 s
# ETA of completion: 33.658385765552524 minutes
#
# Epoch 82 :
# --------------------
# Train accuracy: 75.967857 %
# Train loss: 0.037595
# --------------------
# Validation accuracy: 47.712418 %
# Validation loss: 0.099664
# --------------------
# Elapsed time for epoch: 23.158005714416504 s
# ETA of completion: 45.54407790501912 minutes
#
# Epoch 83 :
# --------------------
# Train accuracy: 75.967857 %
# Train loss: 0.037842
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.086664
# --------------------
# Elapsed time for epoch: 13.589873552322388 s
# ETA of completion: 26.500253427028657 minutes
#
# Epoch 84 :
# --------------------
# Train accuracy: 78.013153 %
# Train loss: 0.035035
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.090213
# --------------------
# Elapsed time for epoch: 24.943808794021606 s
# ETA of completion: 48.224697001775105 minutes
#
# Epoch 85 :
# --------------------
# Train accuracy: 77.867058 %
# Train loss: 0.036547
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.081927
# --------------------
# Elapsed time for epoch: 13.205493211746216 s
# ETA of completion: 25.310528655846912 minutes
#
# Epoch 86 :
# --------------------
# Train accuracy: 78.743614 %
# Train loss: 0.034732
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.084178
# --------------------
# Elapsed time for epoch: 14.201946496963501 s
# ETA of completion: 26.983698344230653 minutes
#
# Epoch 87 :
# --------------------
# Train accuracy: 78.086197 %
# Train loss: 0.033158
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.098959
# --------------------
# Elapsed time for epoch: 16.040534257888794 s
# ETA of completion: 30.20967285235723 minutes
#
# Epoch 88 :
# --------------------
# Train accuracy: 77.355736 %
# Train loss: 0.035646
# --------------------
# Validation accuracy: 47.712418 %
# Validation loss: 0.095118
# --------------------
# Elapsed time for epoch: 18.694692850112915 s
# ETA of completion: 34.89675998687744 minutes
#
# Epoch 89 :
# --------------------
# Train accuracy: 77.063553 %
# Train loss: 0.035610
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.088739
# --------------------
# Elapsed time for epoch: 16.213663339614868 s
# ETA of completion: 29.995277178287505 minutes
#
# Epoch 90 :
# --------------------
# Train accuracy: 78.597519 %
# Train loss: 0.033893
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.102426
# --------------------
# Elapsed time for epoch: 22.812617540359497 s
# ETA of completion: 41.823132157325745 minutes
#
# Epoch 91 :
# --------------------
# Train accuracy: 80.861946 %
# Train loss: 0.030740
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.087969
# --------------------
# Elapsed time for epoch: 22.542876720428467 s
# ETA of completion: 40.95289270877838 minutes
#
# Epoch 92 :
# --------------------
# Train accuracy: 80.204536 %
# Train loss: 0.032903
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.091892
# --------------------
# Elapsed time for epoch: 13.689685583114624 s
# ETA of completion: 24.641434049606325 minutes
#
# Epoch 93 :
# --------------------
# Train accuracy: 77.428780 %
# Train loss: 0.034251
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.084263
# --------------------
# Elapsed time for epoch: 24.43325924873352 s
# ETA of completion: 43.57264566024144 minutes
#
# Epoch 94 :
# --------------------
# Train accuracy: 81.446312 %
# Train loss: 0.031065
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.103796
# --------------------
# Elapsed time for epoch: 15.182421207427979 s
# ETA of completion: 26.822277466456097 minutes
#
# Epoch 95 :
# --------------------
# Train accuracy: 81.008041 %
# Train loss: 0.029743
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.085929
# --------------------
# Elapsed time for epoch: 17.10741877555847 s
# ETA of completion: 29.937982857227325 minutes
#
# Epoch 96 :
# --------------------
# Train accuracy: 81.519356 %
# Train loss: 0.028943
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.091288
# --------------------
# Elapsed time for epoch: 18.979301691055298 s
# ETA of completion: 32.89745626449585 minutes
#
# Epoch 97 :
# --------------------
# Train accuracy: 80.642807 %
# Train loss: 0.033070
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.086543
# --------------------
# Elapsed time for epoch: 20.55995011329651 s
# ETA of completion: 35.29458102782567 minutes
#
# Epoch 98 :
# --------------------
# Train accuracy: 81.081085 %
# Train loss: 0.030510
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.098712
# --------------------
# Elapsed time for epoch: 17.99913477897644 s
# ETA of completion: 30.598529124259947 minutes
#
# Epoch 99 :
# --------------------
# Train accuracy: 81.300224 %
# Train loss: 0.029274
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.088340
# --------------------
# Elapsed time for epoch: 15.19985032081604 s
# ETA of completion: 25.586414706707 minutes
#
# Epoch 100 :
# --------------------
# Train accuracy: 81.738495 %
# Train loss: 0.028531
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.103416
# --------------------
# Elapsed time for epoch: 24.711281538009644 s
# ETA of completion: 41.185469230016075 minutes
#
# Epoch 101 :
# --------------------
# Train accuracy: 82.395912 %
# Train loss: 0.027626
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.096838
# --------------------
# Elapsed time for epoch: 13.526605367660522 s
# ETA of completion: 22.318898856639862 minutes
#
# Epoch 102 :
# --------------------
# Train accuracy: 82.395912 %
# Train loss: 0.028891
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.102772
# --------------------
# Elapsed time for epoch: 16.194097995758057 s
# ETA of completion: 26.45036005973816 minutes
#
# Epoch 103 :
# --------------------
# Train accuracy: 80.204536 %
# Train loss: 0.030593
# --------------------
# Validation accuracy: 47.712418 %
# Validation loss: 0.108903
# --------------------
# Elapsed time for epoch: 23.67573118209839 s
# ETA of completion: 38.27576541105906 minutes
#
# Epoch 104 :
# --------------------
# Train accuracy: 81.738495 %
# Train loss: 0.029179
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.095883
# --------------------
# Elapsed time for epoch: 18.37192702293396 s
# ETA of completion: 29.395083236694337 minutes
#
# Epoch 105 :
# --------------------
# Train accuracy: 81.519356 %
# Train loss: 0.028525
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.108450
# --------------------
# Elapsed time for epoch: 18.34800672531128 s
# ETA of completion: 29.051010648409527 minutes
#
# Epoch 106 :
# --------------------
# Train accuracy: 81.008041 %
# Train loss: 0.030049
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.108234
# --------------------
# Elapsed time for epoch: 13.55352783203125 s
# ETA of completion: 21.23386027018229 minutes
#
# Epoch 107 :
# --------------------
# Train accuracy: 81.373268 %
# Train loss: 0.030109
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.091684
# --------------------
# Elapsed time for epoch: 26.58683156967163 s
# ETA of completion: 41.209588932991025 minutes
#
# Epoch 108 :
# --------------------
# Train accuracy: 83.637695 %
# Train loss: 0.026663
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.098520
# --------------------
# Elapsed time for epoch: 16.18058490753174 s
# ETA of completion: 24.810230191548666 minutes
#
# Epoch 109 :
# --------------------
# Train accuracy: 83.929878 %
# Train loss: 0.026538
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.120863
# --------------------
# Elapsed time for epoch: 22.423625946044922 s
# ETA of completion: 34.00916601816813 minutes
#
# Epoch 110 :
# --------------------
# Train accuracy: 84.075966 %
# Train loss: 0.025739
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.122362
# --------------------
# Elapsed time for epoch: 18.595622062683105 s
# ETA of completion: 27.893433094024658 minutes
#
# Epoch 111 :
# --------------------
# Train accuracy: 82.249817 %
# Train loss: 0.026988
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.105749
# --------------------
# Elapsed time for epoch: 17.439796209335327 s
# ETA of completion: 25.869031043847404 minutes
#
# Epoch 112 :
# --------------------
# Train accuracy: 84.952522 %
# Train loss: 0.025914
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.115177
# --------------------
# Elapsed time for epoch: 19.23203945159912 s
# ETA of completion: 28.20699119567871 minutes
#
# Epoch 113 :
# --------------------
# Train accuracy: 80.934990 %
# Train loss: 0.030136
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.081057
# --------------------
# Elapsed time for epoch: 12.703015565872192 s
# ETA of completion: 18.41937257051468 minutes
#
# Epoch 114 :
# --------------------
# Train accuracy: 83.418556 %
# Train loss: 0.028118
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.118302
# --------------------
# Elapsed time for epoch: 21.442479133605957 s
# ETA of completion: 30.73422009150187 minutes
#
# Epoch 115 :
# --------------------
# Train accuracy: 83.710739 %
# Train loss: 0.026545
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.110078
# --------------------
# Elapsed time for epoch: 13.010722875595093 s
# ETA of completion: 18.431857407093048 minutes
#
# Epoch 116 :
# --------------------
# Train accuracy: 84.952522 %
# Train loss: 0.026637
# --------------------
# Validation accuracy: 60.130722 %
# Validation loss: 0.092945
# --------------------
# Elapsed time for epoch: 18.36741828918457 s
# ETA of completion: 25.7143856048584 minutes
#
# Epoch 117 :
# --------------------
# Train accuracy: 84.806427 %
# Train loss: 0.024946
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.140698
# --------------------
# Elapsed time for epoch: 24.870574474334717 s
# ETA of completion: 34.40429468949636 minutes
#
# Epoch 118 :
# --------------------
# Train accuracy: 83.199417 %
# Train loss: 0.028122
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.102236
# --------------------
# Elapsed time for epoch: 13.281172037124634 s
# ETA of completion: 18.150935117403666 minutes
#
# Epoch 119 :
# --------------------
# Train accuracy: 85.317757 %
# Train loss: 0.024514
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.106699
# --------------------
# Elapsed time for epoch: 23.775577783584595 s
# ETA of completion: 32.0970300078392 minutes
#
# Epoch 120 :
# --------------------
# Train accuracy: 85.975174 %
# Train loss: 0.022815
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.102692
# --------------------
# Elapsed time for epoch: 13.238024711608887 s
# ETA of completion: 17.650699615478516 minutes
#
# Epoch 121 :
# --------------------
# Train accuracy: 83.783791 %
# Train loss: 0.025604
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.095565
# --------------------
# Elapsed time for epoch: 23.79210877418518 s
# ETA of completion: 31.326276552677154 minutes
#
# Epoch 122 :
# --------------------
# Train accuracy: 85.317757 %
# Train loss: 0.025597
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.107844
# --------------------
# Elapsed time for epoch: 17.79023027420044 s
# ETA of completion: 23.127299356460572 minutes
#
# Epoch 123 :
# --------------------
# Train accuracy: 84.295113 %
# Train loss: 0.026191
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.088516
# --------------------
# Elapsed time for epoch: 15.320677757263184 s
# ETA of completion: 19.66153645515442 minutes
#
# Epoch 124 :
# --------------------
# Train accuracy: 86.924767 %
# Train loss: 0.023646
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.118787
# --------------------
# Elapsed time for epoch: 13.348659038543701 s
# ETA of completion: 16.908301448822023 minutes
#
# Epoch 125 :
# --------------------
# Train accuracy: 84.952522 %
# Train loss: 0.025513
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.098392
# --------------------
# Elapsed time for epoch: 24.650660514831543 s
# ETA of completion: 30.81332564353943 minutes
#
# Epoch 126 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.022320
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.129974
# --------------------
# Elapsed time for epoch: 20.239013195037842 s
# ETA of completion: 24.96144960721334 minutes
#
# Epoch 127 :
# --------------------
# Train accuracy: 85.682983 %
# Train loss: 0.024633
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.102518
# --------------------
# Elapsed time for epoch: 18.24969792366028 s
# ETA of completion: 22.203799140453338 minutes
#
# Epoch 128 :
# --------------------
# Train accuracy: 85.536888 %
# Train loss: 0.022873
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.107357
# --------------------
# Elapsed time for epoch: 13.470779180526733 s
# ETA of completion: 16.16493501663208 minutes
#
# Epoch 129 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.022169
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.110302
# --------------------
# Elapsed time for epoch: 18.558735132217407 s
# ETA of completion: 21.961169906457265 minutes
#
# Epoch 130 :
# --------------------
# Train accuracy: 86.340401 %
# Train loss: 0.022635
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.116558
# --------------------
# Elapsed time for epoch: 24.53597617149353 s
# ETA of completion: 28.62530553340912 minutes
#
# Epoch 131 :
# --------------------
# Train accuracy: 85.829071 %
# Train loss: 0.023631
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.111647
# --------------------
# Elapsed time for epoch: 17.31384038925171 s
# ETA of completion: 19.910916447639465 minutes
#
# Epoch 132 :
# --------------------
# Train accuracy: 87.436089 %
# Train loss: 0.020719
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.120613
# --------------------
# Elapsed time for epoch: 14.00884199142456 s
# ETA of completion: 15.876687590281168 minutes
#
# Epoch 133 :
# --------------------
# Train accuracy: 87.436089 %
# Train loss: 0.021180
# --------------------
# Validation accuracy: 46.405228 %
# Validation loss: 0.146588
# --------------------
# Elapsed time for epoch: 23.83336091041565 s
# ETA of completion: 26.613919683297475 minutes
#
# Epoch 134 :
# --------------------
# Train accuracy: 84.441200 %
# Train loss: 0.026104
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.107849
# --------------------
# Elapsed time for epoch: 17.568633794784546 s
# ETA of completion: 19.325497174263 minutes
#
# Epoch 135 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.023066
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.100779
# --------------------
# Elapsed time for epoch: 18.513084888458252 s
# ETA of completion: 20.05584196249644 minutes
#
# Epoch 136 :
# --------------------
# Train accuracy: 87.070862 %
# Train loss: 0.022315
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.096852
# --------------------
# Elapsed time for epoch: 14.696587562561035 s
# ETA of completion: 15.676360066731771 minutes
#
# Epoch 137 :
# --------------------
# Train accuracy: 87.143906 %
# Train loss: 0.021453
# --------------------
# Validation accuracy: 57.516342 %
# Validation loss: 0.116394
# --------------------
# Elapsed time for epoch: 22.8619647026062 s
# ETA of completion: 24.00506293773651 minutes
#
# Epoch 138 :
# --------------------
# Train accuracy: 86.048218 %
# Train loss: 0.022333
# --------------------
# Validation accuracy: 57.516342 %
# Validation loss: 0.114182
# --------------------
# Elapsed time for epoch: 14.307315111160278 s
# ETA of completion: 14.78422561486562 minutes
#
# Epoch 139 :
# --------------------
# Train accuracy: 87.801323 %
# Train loss: 0.020136
# --------------------
# Validation accuracy: 47.712418 %
# Validation loss: 0.111428
# --------------------
# Elapsed time for epoch: 12.804441452026367 s
# ETA of completion: 13.01784880956014 minutes
#
# Epoch 140 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.021804
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.111069
# --------------------
# Elapsed time for epoch: 16.091437101364136 s
# ETA of completion: 16.091437101364136 minutes
#
# Epoch 141 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.022679
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.125542
# --------------------
# Elapsed time for epoch: 25.72675633430481 s
# ETA of completion: 25.297977062066398 minutes
#
# Epoch 142 :
# --------------------
# Train accuracy: 87.947411 %
# Train loss: 0.020542
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.111396
# --------------------
# Elapsed time for epoch: 17.088545322418213 s
# ETA of completion: 16.518927145004273 minutes
#
# Epoch 143 :
# --------------------
# Train accuracy: 87.363037 %
# Train loss: 0.020690
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.125579
# --------------------
# Elapsed time for epoch: 21.8200364112854 s
# ETA of completion: 20.72903459072113 minutes
#
# Epoch 144 :
# --------------------
# Train accuracy: 87.289993 %
# Train loss: 0.021192
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.161095
# --------------------
# Elapsed time for epoch: 16.145373344421387 s
# ETA of completion: 15.06901512145996 minutes
#
# Epoch 145 :
# --------------------
# Train accuracy: 88.604828 %
# Train loss: 0.019532
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.140892
# --------------------
# Elapsed time for epoch: 13.013535499572754 s
# ETA of completion: 11.92907420794169 minutes
#
# Epoch 146 :
# --------------------
# Train accuracy: 87.728271 %
# Train loss: 0.020975
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.102865
# --------------------
# Elapsed time for epoch: 22.026718139648438 s
# ETA of completion: 19.824046325683593 minutes
#
# Epoch 147 :
# --------------------
# Train accuracy: 88.604828 %
# Train loss: 0.019490
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.141561
# --------------------
# Elapsed time for epoch: 23.88803505897522 s
# ETA of completion: 21.10109763542811 minutes
#
# Epoch 148 :
# --------------------
# Train accuracy: 87.363037 %
# Train loss: 0.023238
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.115867
# --------------------
# Elapsed time for epoch: 18.168939113616943 s
# ETA of completion: 15.746413898468017 minutes
#
# Epoch 149 :
# --------------------
# Train accuracy: 88.677872 %
# Train loss: 0.018778
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.136714
# --------------------
# Elapsed time for epoch: 17.557050943374634 s
# ETA of completion: 14.923493301868438 minutes
#
# Epoch 150 :
# --------------------
# Train accuracy: 89.335289 %
# Train loss: 0.016888
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.123737
# --------------------
# Elapsed time for epoch: 15.067054510116577 s
# ETA of completion: 12.555878758430481 minutes
#
# Epoch 151 :
# --------------------
# Train accuracy: 87.728271 %
# Train loss: 0.021361
# --------------------
# Validation accuracy: 56.862747 %
# Validation loss: 0.111971
# --------------------
# Elapsed time for epoch: 14.339000463485718 s
# ETA of completion: 11.71018371184667 minutes
#
# Epoch 152 :
# --------------------
# Train accuracy: 90.138794 %
# Train loss: 0.017914
# --------------------
# Validation accuracy: 56.862747 %
# Validation loss: 0.100626
# --------------------
# Elapsed time for epoch: 22.546276092529297 s
# ETA of completion: 18.037020874023437 minutes
#
# Epoch 153 :
# --------------------
# Train accuracy: 88.458733 %
# Train loss: 0.019418
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.105926
# --------------------
# Elapsed time for epoch: 13.487580060958862 s
# ETA of completion: 10.565271047751109 minutes
#
# Epoch 154 :
# --------------------
# Train accuracy: 87.801323 %
# Train loss: 0.020498
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.123067
# --------------------
# Elapsed time for epoch: 23.55592131614685 s
# ETA of completion: 18.059539675712585 minutes
#
# Epoch 155 :
# --------------------
# Train accuracy: 86.778679 %
# Train loss: 0.021501
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.125742
# --------------------
# Elapsed time for epoch: 14.302171468734741 s
# ETA of completion: 10.726628601551056 minutes
#
# Epoch 156 :
# --------------------
# Train accuracy: 87.289993 %
# Train loss: 0.020608
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.140045
# --------------------
# Elapsed time for epoch: 23.567739963531494 s
# ETA of completion: 17.28300930658976 minutes
#
# Epoch 157 :
# --------------------
# Train accuracy: 88.531784 %
# Train loss: 0.019707
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.114853
# --------------------
# Elapsed time for epoch: 19.612260103225708 s
# ETA of completion: 14.055453073978423 minutes
#
# Epoch 158 :
# --------------------
# Train accuracy: 90.430977 %
# Train loss: 0.017558
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.113701
# --------------------
# Elapsed time for epoch: 13.389065980911255 s
# ETA of completion: 9.372346186637879 minutes
#
# Epoch 159 :
# --------------------
# Train accuracy: 90.650108 %
# Train loss: 0.016532
# --------------------
# Validation accuracy: 56.209152 %
# Validation loss: 0.139930
# --------------------
# Elapsed time for epoch: 16.670785903930664 s
# ETA of completion: 11.391703701019287 minutes
#
# Epoch 160 :
# --------------------
# Train accuracy: 89.919647 %
# Train loss: 0.018416
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.118639
# --------------------
# Elapsed time for epoch: 23.89821696281433 s
# ETA of completion: 15.93214464187622 minutes
#
# Epoch 161 :
# --------------------
# Train accuracy: 88.020454 %
# Train loss: 0.020001
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.124620
# --------------------
# Elapsed time for epoch: 13.697755336761475 s
# ETA of completion: 8.903540968894958 minutes
#
# Epoch 162 :
# --------------------
# Train accuracy: 90.138794 %
# Train loss: 0.018204
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.130379
# --------------------
# Elapsed time for epoch: 23.538964986801147 s
# ETA of completion: 14.908011158307394 minutes
#
# Epoch 163 :
# --------------------
# Train accuracy: 91.672760 %
# Train loss: 0.015685
# --------------------
# Validation accuracy: 59.477127 %
# Validation loss: 0.131821
# --------------------
# Elapsed time for epoch: 13.238887310028076 s
# ETA of completion: 8.163980507850647 minutes
#
# Epoch 164 :
# --------------------
# Train accuracy: 88.677872 %
# Train loss: 0.018567
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.134566
# --------------------
# Elapsed time for epoch: 15.972528219223022 s
# ETA of completion: 9.583516931533813 minutes
#
# Epoch 165 :
# --------------------
# Train accuracy: 89.262238 %
# Train loss: 0.017703
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.137480
# --------------------
# Elapsed time for epoch: 17.41290044784546 s
# ETA of completion: 10.157525261243185 minutes
#
# Epoch 166 :
# --------------------
# Train accuracy: 90.284882 %
# Train loss: 0.018055
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.136499
# --------------------
# Elapsed time for epoch: 24.244192600250244 s
# ETA of completion: 13.738375806808472 minutes
#
# Epoch 167 :
# --------------------
# Train accuracy: 89.992699 %
# Train loss: 0.017663
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.136547
# --------------------
# Elapsed time for epoch: 16.3998281955719 s
# ETA of completion: 9.019905507564545 minutes
#
# Epoch 168 :
# --------------------
# Train accuracy: 91.161438 %
# Train loss: 0.014597
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.131004
# --------------------
# Elapsed time for epoch: 21.875416040420532 s
# ETA of completion: 11.666888554890951 minutes
#
# Epoch 169 :
# --------------------
# Train accuracy: 89.554420 %
# Train loss: 0.018531
# --------------------
# Validation accuracy: 54.901962 %
# Validation loss: 0.141511
# --------------------
# Elapsed time for epoch: 13.43915343284607 s
# ETA of completion: 6.9435626069704695 minutes
#
# Epoch 170 :
# --------------------
# Train accuracy: 88.750916 %
# Train loss: 0.020195
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.122372
# --------------------
# Elapsed time for epoch: 18.80813765525818 s
# ETA of completion: 9.40406882762909 minutes
#
# Epoch 171 :
# --------------------
# Train accuracy: 91.745804 %
# Train loss: 0.015982
# --------------------
# Validation accuracy: 58.823532 %
# Validation loss: 0.132031
# --------------------
# Elapsed time for epoch: 23.63928747177124 s
# ETA of completion: 11.425655611356099 minutes
#
# Epoch 172 :
# --------------------
# Train accuracy: 90.357933 %
# Train loss: 0.017976
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.130123
# --------------------
# Elapsed time for epoch: 14.366301774978638 s
# ETA of completion: 6.704274161656698 minutes
#
# Epoch 173 :
# --------------------
# Train accuracy: 88.385689 %
# Train loss: 0.019419
# --------------------
# Validation accuracy: 59.477127 %
# Validation loss: 0.107186
# --------------------
# Elapsed time for epoch: 13.11067247390747 s
# ETA of completion: 5.899802613258362 minutes
#
# Epoch 174 :
# --------------------
# Train accuracy: 89.554420 %
# Train loss: 0.017492
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.104662
# --------------------
# Elapsed time for epoch: 18.807563304901123 s
# ETA of completion: 8.149944098790487 minutes
#
# Epoch 175 :
# --------------------
# Train accuracy: 91.745804 %
# Train loss: 0.016080
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.120308
# --------------------
# Elapsed time for epoch: 27.577191829681396 s
# ETA of completion: 11.490496595700582 minutes
#
# Epoch 176 :
# --------------------
# Train accuracy: 91.672760 %
# Train loss: 0.015852
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.139146
# --------------------
# Elapsed time for epoch: 13.307726860046387 s
# ETA of completion: 5.323090744018555 minutes
#
# Epoch 177 :
# --------------------
# Train accuracy: 89.335289 %
# Train loss: 0.019212
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.106347
# --------------------
# Elapsed time for epoch: 14.068856954574585 s
# ETA of completion: 5.393061832586924 minutes
#
# Epoch 178 :
# --------------------
# Train accuracy: 90.211838 %
# Train loss: 0.016659
# --------------------
# Validation accuracy: 48.366013 %
# Validation loss: 0.143794
# --------------------
# Elapsed time for epoch: 20.468231678009033 s
# ETA of completion: 7.505018281936645 minutes
#
# Epoch 179 :
# --------------------
# Train accuracy: 91.380569 %
# Train loss: 0.016396
# --------------------
# Validation accuracy: 51.633991 %
# Validation loss: 0.134261
# --------------------
# Elapsed time for epoch: 25.860382556915283 s
# ETA of completion: 9.05113389492035 minutes
#
# Epoch 180 :
# --------------------
# Train accuracy: 91.891899 %
# Train loss: 0.015272
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.155141
# --------------------
# Elapsed time for epoch: 13.382636547088623 s
# ETA of completion: 4.460878849029541 minutes
#
# Epoch 181 :
# --------------------
# Train accuracy: 90.138794 %
# Train loss: 0.016654
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.111867
# --------------------
# Elapsed time for epoch: 14.14248275756836 s
# ETA of completion: 4.478452873229981 minutes
#
# Epoch 182 :
# --------------------
# Train accuracy: 90.650108 %
# Train loss: 0.015248
# --------------------
# Validation accuracy: 52.287586 %
# Validation loss: 0.136901
# --------------------
# Elapsed time for epoch: 22.533193588256836 s
# ETA of completion: 6.759958076477051 minutes
#
# Epoch 183 :
# --------------------
# Train accuracy: 90.504021 %
# Train loss: 0.016804
# --------------------
# Validation accuracy: 52.941177 %
# Validation loss: 0.109703
# --------------------
# Elapsed time for epoch: 14.3761305809021 s
# ETA of completion: 4.073236997922262 minutes
#
# Epoch 184 :
# --------------------
# Train accuracy: 92.476265 %
# Train loss: 0.015483
# --------------------
# Validation accuracy: 47.058823 %
# Validation loss: 0.159969
# --------------------
# Elapsed time for epoch: 16.1459743976593 s
# ETA of completion: 4.305593172709147 minutes
#
# Epoch 185 :
# --------------------
# Train accuracy: 89.481377 %
# Train loss: 0.019968
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.119412
# --------------------
# Elapsed time for epoch: 15.036243200302124 s
# ETA of completion: 3.759060800075531 minutes
#
# Epoch 186 :
# --------------------
# Train accuracy: 92.549309 %
# Train loss: 0.015038
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.116317
# --------------------
# Elapsed time for epoch: 16.27231216430664 s
# ETA of completion: 3.796872838338216 minutes
#
# Epoch 187 :
# --------------------
# Train accuracy: 92.330170 %
# Train loss: 0.013223
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.140130
# --------------------
# Elapsed time for epoch: 16.547414779663086 s
# ETA of completion: 3.585273202260335 minutes
#
# Epoch 188 :
# --------------------
# Train accuracy: 90.796204 %
# Train loss: 0.015894
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.117180
# --------------------
# Elapsed time for epoch: 19.336686849594116 s
# ETA of completion: 3.867337369918823 minutes
#
# Epoch 189 :
# --------------------
# Train accuracy: 92.768448 %
# Train loss: 0.013864
# --------------------
# Validation accuracy: 58.169937 %
# Validation loss: 0.122880
# --------------------
# Elapsed time for epoch: 23.00674057006836 s
# ETA of completion: 4.217902437845866 minutes
#
# Epoch 190 :
# --------------------
# Train accuracy: 91.234482 %
# Train loss: 0.015734
# --------------------
# Validation accuracy: 50.980396 %
# Validation loss: 0.148815
# --------------------
# Elapsed time for epoch: 15.627688884735107 s
# ETA of completion: 2.604614814122518 minutes
#
# Epoch 191 :
# --------------------
# Train accuracy: 91.307526 %
# Train loss: 0.016481
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.123190
# --------------------
# Elapsed time for epoch: 16.008621215820312 s
# ETA of completion: 2.401293182373047 minutes
#
# Epoch 192 :
# --------------------
# Train accuracy: 91.599709 %
# Train loss: 0.013957
# --------------------
# Validation accuracy: 54.248367 %
# Validation loss: 0.152817
# --------------------
# Elapsed time for epoch: 25.15945553779602 s
# ETA of completion: 3.354594071706136 minutes
#
# Epoch 193 :
# --------------------
# Train accuracy: 91.891899 %
# Train loss: 0.014606
# --------------------
# Validation accuracy: 55.555557 %
# Validation loss: 0.136440
# --------------------
# Elapsed time for epoch: 13.511804342269897 s
# ETA of completion: 1.5763771732648213 minutes
#
# Epoch 194 :
# --------------------
# Train accuracy: 90.065750 %
# Train loss: 0.016619
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.110592
# --------------------
# Elapsed time for epoch: 15.547061443328857 s
# ETA of completion: 1.5547061443328858 minutes
#
# Epoch 195 :
# --------------------
# Train accuracy: 90.942299 %
# Train loss: 0.015288
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.175379
# --------------------
# Elapsed time for epoch: 23.30673050880432 s
# ETA of completion: 1.94222754240036 minutes
#
# Epoch 196 :
# --------------------
# Train accuracy: 92.549309 %
# Train loss: 0.013692
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.142893
# --------------------
# Elapsed time for epoch: 22.6980037689209 s
# ETA of completion: 1.5132002512613931 minutes
#
# Epoch 197 :
# --------------------
# Train accuracy: 92.987587 %
# Train loss: 0.013174
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.136672
# --------------------
# Elapsed time for epoch: 20.439279556274414 s
# ETA of completion: 1.0219639778137206 minutes
#
# Epoch 198 :
# --------------------
# Train accuracy: 91.453621 %
# Train loss: 0.016763
# --------------------
# Validation accuracy: 50.326801 %
# Validation loss: 0.128180
# --------------------
# Elapsed time for epoch: 13.34466028213501 s
# ETA of completion: 0.44482200940450034 minutes
#
# Epoch 199 :
# --------------------
# Train accuracy: 92.403214 %
# Train loss: 0.012840
# --------------------
# Validation accuracy: 49.673203 %
# Validation loss: 0.159024
# --------------------
# Elapsed time for epoch: 22.5077645778656 s
# ETA of completion: 0.37512940963109337 minutes
#
# Epoch 200 :
# --------------------
# Train accuracy: 88.970055 %
# Train loss: 0.021426
# --------------------
# Validation accuracy: 53.594772 %
# Validation loss: 0.137471
# --------------------
# Elapsed time for epoch: 15.19100046157837 s
# ETA of completion: 0.0 minutes
# --------------------
# Test accuracy: 47.058823 %
# Test loss: 0.131642
# --------------------

# %%
import gc
del train
#del train_age_dataset
#del train_age_dataloader
#del val_age_dataset
#del val_age_dataloader
#del test_age_dataset
#del test_age_dataloader
gc.collect()
# Out:
# 5436

# %% [markdown]
# # Resnet101

# %%
import torchvision.models as models

class ResNet101(nn.Module):
  def __init__(self, in_channels=3):
    super(ResNet101, self).__init__()

    # Load a pretrained resnet model from torchvision.models in Pytorch
    self.model = models.resnet18(pretrained=True)

    # Change the input layer to take Grayscale image, instead of RGB images. 
    # Hence in_channels is set as 1 or 3 respectively
    # original definition of the first layer on the ResNet class
    # self.conv1 = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
    self.model.conv1 = nn.Conv2d(in_channels, 64,3)

    #i=0
    #for param in self.model.parameters():
    #    if i>39 and i<343:
    #        param.requires_grad = False
    #    i+=1 
    
    # Change the output layer to output 10 classes instead of 1000 classes
    num_ftrs = self.model.fc.in_features
    self.model.fc = nn.Sequential(
        nn.Linear(num_ftrs,512),
        nn.LeakyReLU(),
        nn.Dropout(0.8),
        nn.Linear(512,256),
        nn.LeakyReLU(),
        nn.Dropout(0.5),
        nn.Linear(256, 7))
    #self.model.fc = nn.Linear(num_ftrs, 7)

  def forward(self, x):
    x = self.model(x)
    return F.log_softmax(x,dim=1)

# %%
with torch.no_grad():
  dummy_net = ResNet101()
  dummy_net = dummy_net.cuda()
  summary(dummy_net, (3, 224, 224))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 222, 222]           1,792
#        BatchNorm2d-2         [-1, 64, 222, 222]             128
#               ReLU-3         [-1, 64, 222, 222]               0
#          MaxPool2d-4         [-1, 64, 111, 111]               0
#             Conv2d-5         [-1, 64, 111, 111]          36,864
#        BatchNorm2d-6         [-1, 64, 111, 111]             128
#               ReLU-7         [-1, 64, 111, 111]               0
#             Conv2d-8         [-1, 64, 111, 111]          36,864
#        BatchNorm2d-9         [-1, 64, 111, 111]             128
#              ReLU-10         [-1, 64, 111, 111]               0
#        BasicBlock-11         [-1, 64, 111, 111]               0
#            Conv2d-12         [-1, 64, 111, 111]          36,864
#       BatchNorm2d-13         [-1, 64, 111, 111]             128
#              ReLU-14         [-1, 64, 111, 111]               0
#            Conv2d-15         [-1, 64, 111, 111]          36,864
#       BatchNorm2d-16         [-1, 64, 111, 111]             128
#              ReLU-17         [-1, 64, 111, 111]               0
#        BasicBlock-18         [-1, 64, 111, 111]               0
#            Conv2d-19          [-1, 128, 56, 56]          73,728
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#              ReLU-21          [-1, 128, 56, 56]               0
#            Conv2d-22          [-1, 128, 56, 56]         147,456
#       BatchNorm2d-23          [-1, 128, 56, 56]             256
#            Conv2d-24          [-1, 128, 56, 56]           8,192
#       BatchNorm2d-25          [-1, 128, 56, 56]             256
#              ReLU-26          [-1, 128, 56, 56]               0
#        BasicBlock-27          [-1, 128, 56, 56]               0
#            Conv2d-28          [-1, 128, 56, 56]         147,456
#       BatchNorm2d-29          [-1, 128, 56, 56]             256
#              ReLU-30          [-1, 128, 56, 56]               0
#            Conv2d-31          [-1, 128, 56, 56]         147,456
#       BatchNorm2d-32          [-1, 128, 56, 56]             256
#              ReLU-33          [-1, 128, 56, 56]               0
#        BasicBlock-34          [-1, 128, 56, 56]               0
#            Conv2d-35          [-1, 256, 28, 28]         294,912
#       BatchNorm2d-36          [-1, 256, 28, 28]             512
#              ReLU-37          [-1, 256, 28, 28]               0
#            Conv2d-38          [-1, 256, 28, 28]         589,824
#       BatchNorm2d-39          [-1, 256, 28, 28]             512
#            Conv2d-40          [-1, 256, 28, 28]          32,768
#       BatchNorm2d-41          [-1, 256, 28, 28]             512
#              ReLU-42          [-1, 256, 28, 28]               0
#        BasicBlock-43          [-1, 256, 28, 28]               0
#            Conv2d-44          [-1, 256, 28, 28]         589,824
#       BatchNorm2d-45          [-1, 256, 28, 28]             512
#              ReLU-46          [-1, 256, 28, 28]               0
#            Conv2d-47          [-1, 256, 28, 28]         589,824
#       BatchNorm2d-48          [-1, 256, 28, 28]             512
#              ReLU-49          [-1, 256, 28, 28]               0
#        BasicBlock-50          [-1, 256, 28, 28]               0
#            Conv2d-51          [-1, 512, 14, 14]       1,179,648
#       BatchNorm2d-52          [-1, 512, 14, 14]           1,024
#              ReLU-53          [-1, 512, 14, 14]               0
#            Conv2d-54          [-1, 512, 14, 14]       2,359,296
#       BatchNorm2d-55          [-1, 512, 14, 14]           1,024
#            Conv2d-56          [-1, 512, 14, 14]         131,072
#       BatchNorm2d-57          [-1, 512, 14, 14]           1,024
#              ReLU-58          [-1, 512, 14, 14]               0
#        BasicBlock-59          [-1, 512, 14, 14]               0
#            Conv2d-60          [-1, 512, 14, 14]       2,359,296
#       BatchNorm2d-61          [-1, 512, 14, 14]           1,024
#              ReLU-62          [-1, 512, 14, 14]               0
#            Conv2d-63          [-1, 512, 14, 14]       2,359,296
#       BatchNorm2d-64          [-1, 512, 14, 14]           1,024
#              ReLU-65          [-1, 512, 14, 14]               0
#        BasicBlock-66          [-1, 512, 14, 14]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 512]         262,656
#         LeakyReLU-69                  [-1, 512]               0
#           Dropout-70                  [-1, 512]               0
#            Linear-71                  [-1, 256]         131,328
#         LeakyReLU-72                  [-1, 256]               0
#           Dropout-73                  [-1, 256]               0
#            Linear-74                    [-1, 7]           1,799
#            ResNet-75                    [-1, 7]               0
# ================================================================
# Total params: 11,564,679
# Trainable params: 11,564,679
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 248.21
# Params size (MB): 44.12
# Estimated Total Size (MB): 292.90
# ----------------------------------------------------------------

# %%
## Hyperparameters
EPOCH = 200
LR = 0.0001

## Setting up the model, optimizer, and loss function
model = ResNet101()
model_name = "resnet101"
optimizer = optim.Adam
loss_f = nn.NLLLoss

# %%
## Run Training Loop
out = train(model,
            model_name, 
            optimizer, 
            loss_f,
            LR,
            epochs = EPOCH,
            train_dataloader = train_age_dataloader,
            val_dataloader = val_age_dataloader,
            test_dataloader = test_age_dataloader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a1c4888127b3> in <module>()
#       1 ## Run Training Loop
# ----> 2 out = train(model,
#       3             model_name,
#       4             optimizer,
#       5             loss_f,
#
# NameError: name 'train' is not defined

# %%
del model
del train
